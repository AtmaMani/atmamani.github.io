# %% [markdown]
# # An introduction to geocoding
#
# Geocoders are tools to which you pass in an address / place of interest and it gives back the coordinates of that place.
#
# The **`arcgis.geocoding`** module provides types and functions for geocoding, batch geocoding and reverse geocoding.
#
# ![](geocoding_module.png)

# %% [markdown]
# ## Default geocoders in your GIS
#
# Call `geocoding.get_geocoders()` to get a list of `Geocoder` objects.

# %%
from arcgis.gis import GIS
from arcgis import geocoding
from getpass import getpass
password = getpass()
# Out:
# ········

# %%
gis = GIS("http://esriwebgis.webgistesting.net/portal", "atma.mani", password)

# %% [markdown]
# Your GIS can have multiple geocoders. The first one in the list is the active or default one.
# You can optionally turn off a geocoder by setting the `set_active` property to `False`

# %% [markdown]
# ## Geocoding addresses
# All geocoding operations are handled by `geocode()` function. It can geocode
#
#  1. single line address
#  2. multi field address
#  3. points of interest
#  4. administrative place names
#  5. postal codes

# %%
results = geocoding.geocode('Palm Springs, CA')
results
# Out:
# [{'address': 'Palm Springs, California, United States',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'Addr_type': 'POI',
#    'City': '',
#    'Country': 'USA',
#    'DisplayX': -116.545291,
#    'DisplayY': 33.830299,
#    'Distance': 0,
#    'LangCode': '',
#    'Loc_name': 'Gaz.WorldGazetteer.POI1',
#    'Match_addr': 'Palm Springs, California, United States',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'Palm Springs',
#    'Place_addr': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': '8.69',
#    'Region': 'California',
#    'Score': 100,
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Subregion': 'Riverside',
#    'Type': 'City',
#    'URL': '',
#    'X': -116.545291,
#    'Xmax': -116.405291,
#    'Xmin': -116.685291,
#    'Y': 33.830299,
#    'Ymax': 33.970299,
#    'Ymin': 33.690299},
#   'extent': {'xmax': -116.405291,
#    'xmin': -116.685291,
#    'ymax': 33.970299,
#    'ymin': 33.690299},
#   'location': {'x': -116.54528957999969, 'y': 33.83029877300049},
#   'score': 100},
#  {'address': 'Palm Springs',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'Addr_type': 'POI',
#    'City': 'Palm Desert',
#    'Country': 'USA',
#    'DisplayX': -116.309759,
#    'DisplayY': 33.762746,
#    'Distance': 0,
#    'LangCode': 'ENG',
#    'Loc_name': 'Gaz.WorldGazetteer.POI2',
#    'Match_addr': 'Palm Springs',
#    'Nbrhd': '',
#    'Phone': '(760)345-2236',
#    'PlaceName': 'Palm Springs',
#    'Place_addr': '77500 Varner Rd, Palm Desert, California',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': '22',
#    'Region': 'California',
#    'Score': 100,
#    'Side': '',
#    'StAddr': '77500 Varner Rd',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Subregion': 'Riverside',
#    'Type': 'Campground',
#    'URL': 'http://palmsprings.com',
#    'X': -116.309759,
#    'Xmax': -116.304759,
#    'Xmin': -116.314759,
#    'Y': 33.762746,
#    'Ymax': 33.767746,
#    'Ymin': 33.757746},
#   'extent': {'xmax': -116.304759,
#    'xmin': -116.314759,
#    'ymax': 33.767746,
#    'ymin': 33.757746},
#   'location': {'x': -116.30975798099968, 'y': 33.762746267000466},
#   'score': 100},
#  {'address': 'Palm Spring, California, United States',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'Addr_type': 'POI',
#    'City': '',
#    'Country': 'USA',
#    'DisplayX': -117.766019,
#    'DisplayY': 36.813057,
#    'Distance': 0,
#    'LangCode': '',
#    'Loc_name': 'Gaz.WorldGazetteer.POI1',
#    'Match_addr': 'Palm Spring, California, United States',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'Palm Spring',
#    'Place_addr': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': '30',
#    'Region': 'California',
#    'Score': 100,
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Subregion': 'Inyo County',
#    'Type': 'Spring',
#    'URL': '',
#    'X': -117.766019,
#    'Xmax': -117.761019,
#    'Xmin': -117.771019,
#    'Y': 36.813057,
#    'Ymax': 36.818057,
#    'Ymin': 36.808057},
#   'extent': {'xmax': -117.761019,
#    'xmin': -117.771019,
#    'ymax': 36.818057,
#    'ymin': 36.808057},
#   'location': {'x': -117.76601775599971, 'y': 36.813057089000495},
#   'score': 100},
#  {'address': 'Palm Spring, California, United States',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'Addr_type': 'POI',
#    'City': '',
#    'Country': 'USA',
#    'DisplayX': -116.218071,
#    'DisplayY': 32.919989,
#    'Distance': 0,
#    'LangCode': '',
#    'Loc_name': 'Gaz.WorldGazetteer.POI1',
#    'Match_addr': 'Palm Spring, California, United States',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'Palm Spring',
#    'Place_addr': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': '30',
#    'Region': 'California',
#    'Score': 100,
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Subregion': 'San Diego County',
#    'Type': 'Spring',
#    'URL': '',
#    'X': -116.218071,
#    'Xmax': -116.213071,
#    'Xmin': -116.223071,
#    'Y': 32.919989,
#    'Ymax': 32.924989,
#    'Ymin': 32.914989},
#   'extent': {'xmax': -116.213071,
#    'xmin': -116.223071,
#    'ymax': 32.924989,
#    'ymin': 32.914989},
#   'location': {'x': -116.21806961699968, 'y': 32.91998905200046},
#   'score': 100}]

# %%
len(results)
# Out:
# 4

# %%
results[0]
# Out:
# {'address': 'Palm Springs, California, United States',
#  'attributes': {'AddBldg': '',
#   'AddNum': '',
#   'AddNumFrom': '',
#   'AddNumTo': '',
#   'Addr_type': 'POI',
#   'City': '',
#   'Country': 'USA',
#   'DisplayX': -116.545291,
#   'DisplayY': 33.830299,
#   'Distance': 0,
#   'LangCode': '',
#   'Loc_name': 'Gaz.WorldGazetteer.POI1',
#   'Match_addr': 'Palm Springs, California, United States',
#   'Nbrhd': '',
#   'Phone': '',
#   'PlaceName': 'Palm Springs',
#   'Place_addr': '',
#   'Postal': '',
#   'PostalExt': '',
#   'Rank': '8.69',
#   'Region': 'California',
#   'Score': 100,
#   'Side': '',
#   'StAddr': '',
#   'StDir': '',
#   'StName': '',
#   'StPreDir': '',
#   'StPreType': '',
#   'StType': '',
#   'Subregion': 'Riverside',
#   'Type': 'City',
#   'URL': '',
#   'X': -116.545291,
#   'Xmax': -116.405291,
#   'Xmin': -116.685291,
#   'Y': 33.830299,
#   'Ymax': 33.970299,
#   'Ymin': 33.690299},
#  'extent': {'xmax': -116.405291,
#   'xmin': -116.685291,
#   'ymax': 33.970299,
#   'ymin': 33.690299},
#  'location': {'x': -116.54528957999969, 'y': 33.83029877300049},
#  'score': 100}

# %%
map1 = gis.map('Palm Springs, CA')
map1

# %%
map1.draw(results[0]['location'])

# %% [markdown]
# ### Geocode single line addresses

# %%
r2 = geocoding.geocode('150 S Indian Canyon Dr, Palm Springs, CA')
len(r2)
# Out:
# 15

# %%
[r['score'] for r in r2]
# Out:
# [100,
#  100,
#  92.43,
#  79,
#  100,
#  100,
#  90.54,
#  90.54,
#  89.56,
#  100,
#  95.48,
#  95.48,
#  95.48,
#  94.29,
#  89.77]

# %%
[str(r['score']) +"  :  "+ r['attributes']['Match_addr'] for r in r2]
# Out:
# ['100  :  150 S Indian Canyon Dr, Palm Springs, California, 92262',
#  '100  :  150 S Indian Canyon Dr, Palm Springs, California, 92262',
#  '92.43  :  150 N Indian Canyon Dr, Palm Springs, California, 92262',
#  '79  :  151 S Indian Canyon Dr, Palm Springs, California, 92262',
#  '100  :  S Indian Canyon Dr, Palm Springs, California, 92264',
#  '100  :  S Indian Canyon Dr, Palm Springs, California, 92262',
#  '90.54  :  N Indian Canyon Dr, Palm Springs, California, 92262',
#  '90.54  :  N Indian Canyon Dr, Palm Springs, California, 92258',
#  '89.56  :  N Indian Canyon Dr, North Palm Springs, California, 92258',
#  '100  :  Palm Springs, California',
#  '95.48  :  Palm Springs, Florida',
#  '95.48  :  Palm Springs, Arizona',
#  '95.48  :  Palm Springs, Florida',
#  '94.29  :  North Palm Springs, California',
#  '89.77  :  Palm Springs Estates, Florida']

# %% [markdown]
# ### Geocode multi field address

# %%
multi_field_address = { 
    "Address" : "150 S Indian Canyon Dr",
    "City" : "Palm Springs",
    "Region" : "CA",
    "Subregion":"Riverside",
    "Postal" : 92262,
    "Country":"USA"
    }
r_multi_fields = geocoding.geocode(multi_field_address)
len(r_multi_fields)
# Out:
# 9

# %%
[str(r['score']) +"  :  "+ r['attributes']['Match_addr'] for r in r_multi_fields]
# Out:
# ['100  :  150 S Indian Canyon Dr, Palm Springs, California, 92262',
#  '100  :  150 S Indian Canyon Dr, Palm Springs, California, 92262',
#  '92.43  :  150 N Indian Canyon Dr, Palm Springs, California, 92262',
#  '79  :  151 S Indian Canyon Dr, Palm Springs, California, 92262',
#  '100  :  S Indian Canyon Dr, Palm Springs, California, 92262',
#  '90.54  :  N Indian Canyon Dr, Palm Springs, California, 92262',
#  '100  :  92262, Palm Springs, California',
#  '100  :  Palm Springs, California',
#  '96.54  :  North Palm Springs, California']

# %%
map2 = gis.map("Palm Springs, CA", zoomlevel=15)
map2

# %%
map2.center = [r_multi_fields[0]['location']['y'],r_multi_fields[0]['location']['x']]

# %%
map2.draw(r_multi_fields[0]['location'])

# %% [markdown]
# ### Searching within an exent
# Find restaurants within walking distance of this training center (Hard Rock Hotel, Palm Springs)

# %%
# first create an extent. to do that lets geocode Hard Rock hotel and get the extent for the first result
hard_rock = geocoding.geocode('150 S Indian Canyon Dr, Palm Springs, California')[0]
map3 = gis.map('150 S Indian Canyon Dr, Palm Springs, California', zoomlevel=17)
map3

# %%
restaurants = geocoding.geocode('restaurant',search_extent=hard_rock['extent'], max_locations=15)
len(restaurants)
# Out:
# 12

# %%
for shop in restaurants:
    map3.draw(shop['location'])

# %%
restaurants[0]
# Out:
# {'address': "Oscar's Bar and Cafe",
#  'attributes': {'AddBldg': '',
#   'AddNum': '',
#   'AddNumFrom': '',
#   'AddNumTo': '',
#   'Addr_type': 'POI',
#   'City': 'Palm Springs',
#   'Country': 'USA',
#   'DisplayX': -116.546501,
#   'DisplayY': 33.823068,
#   'Distance': 0,
#   'LangCode': 'ENG',
#   'Loc_name': 'Gaz.WorldGazetteer.POI2',
#   'Match_addr': "Oscar's Bar and Cafe",
#   'Nbrhd': '',
#   'Phone': '(760)325-1188',
#   'PlaceName': "Oscar's Bar and Cafe",
#   'Place_addr': '125 E Tahquitz Canyon Way, Palm Springs, California',
#   'Postal': '',
#   'PostalExt': '',
#   'Rank': '19',
#   'Region': 'California',
#   'Score': 100,
#   'Side': '',
#   'StAddr': '125 E Tahquitz Canyon Way',
#   'StDir': '',
#   'StName': '',
#   'StPreDir': '',
#   'StPreType': '',
#   'StType': '',
#   'Subregion': 'Riverside',
#   'Type': 'American Food',
#   'URL': '',
#   'X': -116.546501,
#   'Xmax': -116.541501,
#   'Xmin': -116.551501,
#   'Y': 33.823068,
#   'Ymax': 33.828068,
#   'Ymin': 33.818068},
#  'extent': {'xmax': -116.541501,
#   'xmin': -116.551501,
#   'ymax': 33.828068,
#   'ymin': 33.818068},
#  'location': {'x': -116.5464999729997, 'y': 33.82306791500048},
#  'score': 100}

# %%
for shop in restaurants:
    popup = { 
    "title" : shop['attributes']['PlaceName'], 
    "content" : shop['attributes']['Place_addr']
    }
    map3.draw(shop['location'],popup)

# %% [markdown]
# ### Exercise: Find restaurants near by the devsummit convention center, filter out the Mexican restaurants

# %%
conv_center = geocoding.geocode("Palm Springs Convention Center")[0]
conv_center['location']
conv_center['extent']
# Out:
# {'xmax': -116.531971,
#  'xmin': -116.541971,
#  'ymax': 33.830849,
#  'ymin': 33.820849}

# %%
map4 = gis.map("Palm Springs Convention Center")
map4

# %%
m_restaurants = geocoding.geocode('restaurant',search_extent=conv_center['extent'], max_locations=15)
len(m_restaurants)
# Out:
# 4

# %%
[str(r['score']) +"  :  "+ r['attributes']['Match_addr'] for r in m_restaurants]
# Out:
# ['100  :  Blame It on Midnight',
#  '100  :  Date',
#  "100  :  Shakey's",
#  "100  :  Margarita's Restaurant"]

# %%
m_restaurants2 = geocoding.geocode("",category = 'Mexican Food' ,search_extent=conv_center['extent'], max_locations=15)
len(m_restaurants2)
# Out:
# Unable to complete operation.
# The category value entered is not a supported value.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-56-2f1a615daf8b> in <module>()
# ----> 1 m_restaurants2 = geocoding.geocode("",category = 'Mexican' ,search_extent=conv_center['extent'], max_locations=15)
#       2 len(m_restaurants2)
#
# C:\Users\atma6951\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\geonuma_server\lib\site-packages\arcgis\geocoding\_functions.py in geocode(address, search_extent, location, distance, out_sr, category, out_fields, max_locations, magic_key, for_storage, geocoder)
#     510         max_locations,
#     511         magic_key,
# --> 512         for_storage)
#     513
#     514
#
# C:\Users\atma6951\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\geonuma_server\lib\site-packages\arcgis\geocoding\_functions.py in _geocode(self, address, search_extent, location, distance, out_sr, category, out_fields, max_locations, magic_key, for_storage)
#     163             params['forStorage'] = for_storage
#     164
# --> 165         resp = self._con.post(url, params, token=self._token)
#     166
#     167         if resp is not None:
#
# C:\Users\atma6951\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\geonuma_server\lib\site-packages\arcgis\_impl\connection.py in post(self, path, postdata, files, ssl, compress, is_retry, use_ordered_dict, add_token, verify_cert, token)
#     927                 elif errorcode == 498:
#     928                     raise RuntimeError('Invalid token')
# --> 929                 self._handle_json_error(resp_json['error'], errorcode)
#     930                 return None
#     931         except AttributeError:
#
# C:\Users\atma6951\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\geonuma_server\lib\site-packages\arcgis\_impl\connection.py in _handle_json_error(self, error, errorcode)
#     947
#     948         errormessage = errormessage + "\n(Error Code: " + str(errorcode) +")"
# --> 949         raise RuntimeError(errormessage)
#     950
#     951 class _StrictURLopener(request.FancyURLopener):
#
# RuntimeError: Unable to complete operation.
# The category value entered is not a supported value.
# (Error Code: 400)

# %%
[str(r['score']) +"  :  "+ r['attributes']['Match_addr'] for r in m_restaurants2]
# Out:
# ['100  :  Blame It on Midnight',
#  '100  :  Date',
#  "100  :  Shakey's",
#  "100  :  Margarita's Restaurant"]

# %%
m_restaurants2[0]
# Out:
# {'address': "Margarita's Restaurant",
#  'attributes': {'AddBldg': '',
#   'AddNum': '',
#   'AddNumFrom': '',
#   'AddNumTo': '',
#   'Addr_type': 'POI',
#   'City': 'Palm Springs',
#   'Country': 'USA',
#   'DisplayX': -116.536917,
#   'DisplayY': 33.823198,
#   'Distance': 0,
#   'LangCode': 'ENG',
#   'Loc_name': 'Gaz.WorldGazetteer.POI2',
#   'Match_addr': "Margarita's Restaurant",
#   'Nbrhd': '',
#   'Phone': '(760)778-3500',
#   'PlaceName': "Margarita's Restaurant",
#   'Place_addr': '1000 E Tahquitz Canyon Way, Palm Springs, California',
#   'Postal': '',
#   'PostalExt': '',
#   'Rank': '19',
#   'Region': 'California',
#   'Score': 100,
#   'Side': '',
#   'StAddr': '1000 E Tahquitz Canyon Way',
#   'StDir': '',
#   'StName': '',
#   'StPreDir': '',
#   'StPreType': '',
#   'StType': '',
#   'Subregion': 'Riverside',
#   'Type': 'Mexican Food',
#   'URL': 'http://www.margaritasrestaurant.net/',
#   'X': -116.536917,
#   'Xmax': -116.531917,
#   'Xmin': -116.541917,
#   'Y': 33.823198,
#   'Ymax': 33.828198,
#   'Ymin': 33.818198},
#  'extent': {'xmax': -116.531917,
#   'xmin': -116.541917,
#   'ymax': 33.828198,
#   'ymin': 33.818198},
#  'location': {'x': -116.53691582399972, 'y': 33.82319840300045},
#  'score': 100}

# %%
map4.draw(m_restaurants2[0]['location'])

# %% [markdown]
# ## Looking for geocoders in arcgis.com
#
# Geocoding services can be published as items in the GIS.

# %%
from IPython.display import display

arcgis_online = GIS() #connecting anonymously
search_result = arcgis_online.content.search('Geocoder', item_type='geocoding service', max_items=3)
for item in search_result:
    display(item)
# Out:
# <Item title:"World Geocoding" type:Geocoding Service owner:esri>
# <Item title:"Esri Nederland BAG Geocoder" type:Geocoding Service owner:Esri_NL_Content>
# <Item title:"VGIN Composite Geocoding Service" type:Geocoding Service owner:VGIN>

# %% [markdown]
# ### Creating a `Geocoder` object from a geocoding layer item

# %%
world_geocoding_item = search_result[0]
world_geocoder = geocoding.Geocoder.fromitem(world_geocoding_item)
world_geocoder
# Out:
# <Geocoder url:"http://geocode.arcgis.com/arcgis/rest/services/World/GeocodeServer">

# %%
type(world_geocoder)
# Out:
# arcgis.geocoding._functions.Geocoder

# %%
world_geocoder.properties.capabilities
# Out:
# 'Geocode,ReverseGeocode,Suggest'

# %%
world_geocoder.properties.currentVersion
# Out:
# 10.41

# %% [markdown]
# ### Creating a `Geocoder` from a geocoding service

# %%
geocoder_url = 'https://services.arcgisonline.nl/arcgis/rest/services/Geocoder_BAG_RD/GeocodeServer'
esrinl_geocoder = geocoding.Geocoder(geocoder_url, gis)
esrinl_geocoder
# Out:
# <Geocoder url:"https://services.arcgisonline.nl/arcgis/rest/services/Geocoder_BAG_RD/GeocodeServer">

# %% [markdown]
# <hr>
# <a id="properties-of-a-geocoder"></a>
# ## Properties of a `geocoder`

# %%
[prop_name for prop_name in world_geocoder.properties.keys()]
# Out:
# ['singleLineAddressField',
#  'serviceDescription',
#  'countries',
#  'candidateFields',
#  'capabilities',
#  'addressFields',
#  'locatorProperties',
#  'categories',
#  'currentVersion',
#  'spatialReference']

# %%
world_geocoder.properties.categories
# Out:
# [{
#    "localizedNames": {
#      "zh-cn": "\u5730\u5740",
#      "th": "\u0e17\u0e35\u0e48\u0e2d\u0e22\u0e39\u0e48",
#      "nb": "Adresse",
#      "et": "Aadress",
#      "tr": "Adres",
#      "zh-tw": "\u5730\u5740",
#      "pt-br": "Endere\u00e7o",
#      "nl": "Adres",
#      "es": "Direcci\u00f3n",
#      "it": "Indirizzo",
#      "da": "Adresse",
#      "pl": "Adres",
#      "ro": "Adres\u0103",
#      "lt": "Adresas",
#      "ja": "\u30a2\u30c9\u30ec\u30b9\u8a73\u7d30",
#      "lv": "Adrese",
#      "ru": "\u0410\u0434\u0440\u0435\u0441",
#      "he": "\u05db\u05ea\u05d5\u05d1\u05ea",
#      "ar": "\u0639\u0646\u0648\u0627\u0646",
#      "cs": "Adresa",
#      "hr": "Adresa",
#      "ko": "\uc8fc\uc18c",
#      "sr": "Adresa",
#      "zh-hk": "\u5730\u5740",
#      "vi": "\u0110\u1ecba ch\u1ec9",
#      "fi": "Osoite",
#      "sv": "Adress",
#      "fr": "Adresse",
#      "pt-pt": "Endere\u00e7o",
#      "el": "\u0394\u03b9\u03b5\u03cd\u03b8\u03c5\u03bd\u03c3\u03b7",
#      "de": "Adresse"
#    },
#    "categories": [
#      {
#        "localizedNames": {
#          "zh-cn": "\u70b9\u5730\u5740",
#          "th": "\u0e15\u0e33\u0e41\u0e2b\u0e19\u0e48\u0e07\u0e17\u0e35\u0e48\u0e2d\u0e22\u0e39\u0e48",
#          "nb": "Punktadresse",
#          "et": "Punkti aadress",
#          "tr": "Nokta Adresi",
#          "zh-tw": "\u9ede\u5730\u5740",
#          "pt-br": "Endere\u00e7o do Ponto",
#          "nl": "Puntadres",
#          "es": "Direcci\u00f3n de punto",
#          "it": "Indirizzo punto",
#          "da": "Punktadresse",
#          "pl": "Adres punktu",
#          "ro": "Adres\u0103 punctual\u0103",
#          "lt": "Ta\u0161kinis adresas",
#          "ja": "\u30dd\u30a4\u30f3\u30c8 \u30a2\u30c9\u30ec\u30b9",
#          "lv": "Nor\u0101d\u012bt adresi",
#          "ru": "\u0410\u0434\u0440\u0435\u0441 \u0442\u043e\u0447\u043a\u0438",
#          "he": "\u05db\u05ea\u05d5\u05d1\u05ea \u05e0\u05e7\u05d5\u05d3\u05ea \u05e2\u05e0\u05d9\u05d9\u05df",
#          "ar": "\u0639\u0646\u0648\u0627\u0646 \u0627\u0644\u0646\u0642\u0637\u0629",
#          "cs": "Adresa bodu",
#          "hr": "Adresa to\u010dke",
#          "ko": "\ud3ec\uc778\ud2b8 \uc8fc\uc18c",
#          "sr": "Adresa ta\u010dke",
#          "zh-hk": "\u9ede\u5730\u5740",
#          "vi": "\u0110\u1ecba ch\u1ec9 \u0110i\u1ec3m",
#          "fi": "Pisteen osoite",
#          "sv": "Punktens adress",
#          "fr": "Adresse du point",
#          "pt-pt": "Endere\u00e7o de Ponto",
#          "el": "\u0394\u03b9\u03b5\u03cd\u03b8\u03c5\u03bd\u03c3\u03b7 \u03c3\u03b7\u03bc\u03b5\u03af\u03bf\u03c5",
#          "de": "Punktadresse"
#        },
#        "name": "Point Address"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "\u5efa\u7b51\u7269\u540d\u79f0",
#          "th": "\u0e0a\u0e37\u0e48\u0e2d\u0e2d\u0e32\u0e04\u0e32\u0e23",
#          "nb": "Navn p\u00e5 bygning",
#          "et": "Ehitise nimi",
#          "tr": "Bina Ad\u0131",
#          "zh-tw": "\u5efa\u7bc9\u7269\u540d\u7a31",
#          "pt-br": "Nome do Edif\u00edcio",
#          "nl": "Naam van gebouw",
#          "es": "Nombre del edificio",
#          "it": "Nome edificio",
#          "da": "Bygningens navn",
#          "pl": "Nazwa budynku",
#          "ro": "Denumire cl\u0103dire",
#          "lt": "Pastato pavadinimas",
#          "ja": "\u5efa\u7269\u540d",
#          "lv": "\u0112kas nosaukums",
#          "ru": "\u041d\u0430\u0437\u0432\u0430\u043d\u0438\u0435 \u0437\u0434\u0430\u043d\u0438\u044f",
#          "he": "\u05e9\u05dd \u05d1\u05e0\u05d9\u05d9\u05df",
#          "ar": "\u0627\u0633\u0645 \u0627\u0644\u0645\u0628\u0646\u064a",
#          "cs": "N\u00e1zev budovy",
#          "hr": "Naziv zgrade",
#          "ko": "\uac74\ubb3c \uc774\ub984",
#          "sr": "Ime zgrade",
#          "zh-hk": "\u5efa\u7bc9\u7269\u540d\u7a31",
#          "vi": "T\u00ean T\u00f2a nh\u00e0",
#          "fi": "Rakennuksen nimi",
#          "sv": "Byggnadens namn",
#          "fr": "Nom de b\u00e2timent",
#          "pt-pt": "Nome do Edif\u00edcio",
#          "el": "\u038c\u03bd\u03bf\u03bc\u03b1 \u03ba\u03c4\u03b9\u03c1\u03af\u03bf\u03c5",
#          "de": "Name des Geb\u00e4udes"
#        },
#        "name": "Building Name"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "\u8857\u9053\u5730\u5740",
#          "th": "\u0e17\u0e35\u0e48\u0e2d\u0e22\u0e39\u0e48\u0e16\u0e19\u0e19",
#          "nb": "Gateadresse",
#          "et": "T\u00e4nava aadress",
#          "tr": "Sokak Adresi",
#          "zh-tw": "\u8857\u9053\u5730\u5740",
#          "pt-br": "Endere\u00e7o da Rua",
#          "nl": "Adres met straatnaam",
#          "es": "Calle",
#          "it": "Indirizzo stradale",
#          "da": "Gade",
#          "pl": "Adres ulicy",
#          "ro": "Adres\u0103 stradal\u0103",
#          "lt": "Adresas",
#          "ja": "\u4f4f\u6240",
#          "lv": "Ielas adrese",
#          "ru": "\u0423\u043b\u0438\u0446\u0430",
#          "he": "\u05db\u05ea\u05d5\u05d1\u05ea \u05e8\u05d7\u05d5\u05d1",
#          "ar": "\u0639\u0646\u0648\u0627\u0646 \u0627\u0644\u0634\u0627\u0631\u0639",
#          "cs": "Adresa ulice",
#          "hr": "Adresa ulice",
#          "ko": "\ub3c4\ub85c \uc8fc\uc18c",
#          "sr": "Adresa ulice",
#          "zh-hk": "\u8857\u9053\u5730\u5740",
#          "vi": "\u0110\u1ecba ch\u1ec9 \u0110\u01b0\u1eddng ph\u1ed1",
#          "fi": "Katuosoite",
#          "sv": "Gatuadress",
#          "fr": "Adresse",
#          "pt-pt": "Endere\u00e7o de Rua",
#          "el": "\u039f\u03b4\u03cc\u03c2 \u03ba\u03b1\u03b9 \u03b1\u03c1\u03b9\u03b8\u03bc\u03cc\u03c2",
#          "de": "Stra\u00dfenadresse"
#        },
#        "name": "Street Address"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "\u5341\u5b57\u8def\u53e3",
#          "th": "\u0e17\u0e32\u0e07\u0e41\u0e22\u0e01",
#          "nb": "Kryss",
#          "et": "Ristmik",
#          "tr": "Kesi\u015fim",
#          "zh-tw": "\u5341\u5b57\u8def\u53e3",
#          "pt-br": "Intersec\u00e7\u00e3o",
#          "nl": "Kruispunt",
#          "es": "Intersecar",
#          "it": "Incrocio",
#          "da": "Vejkryds",
#          "pl": "Przeci\u0119cie",
#          "ro": "Intersec\u0163ie",
#          "lt": "Sankry\u017ea",
#          "ja": "\u4ea4\u5dee\u70b9",
#          "lv": "Krustpunkts",
#          "ru": "\u041f\u0435\u0440\u0435\u0441\u0435\u0447\u0435\u043d\u0438\u0435",
#          "he": "\u05d7\u05d9\u05ea\u05d5\u05da",
#          "ar": "\u062a\u0642\u0627\u0637\u0639",
#          "cs": "Pr\u016fse\u010d\u00edk",
#          "hr": "Raskri\u017eje",
#          "ko": "\uad50\ucc28\ub85c",
#          "sr": "Raskrsnica",
#          "zh-hk": "\u5341\u5b57\u8def\u53e3",
#          "vi": "Giao l\u1ed9",
#          "fi": "Risteys",
#          "sv": "Korsning",
#          "fr": "Intersection",
#          "pt-pt": "intersec\u00e7\u00e3o",
#          "el": "\u0394\u03b9\u03b1\u03c3\u03c4\u03b1\u03cd\u03c1\u03c9\u03c3\u03b7",
#          "de": "Schnittpunkt"
#        },
#        "name": "Intersection"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "\u8857\u9053\u540d\u79f0",
#          "th": "\u0e0a\u0e37\u0e48\u0e2d\u0e16\u0e19\u0e19",
#          "nb": "Gatenavn",
#          "et": "T\u00e4nava nimi",
#          "tr": "Sokak Ad\u0131",
#          "zh-tw": "\u8857\u9053\u540d\u7a31",
#          "pt-br": "Nome da Rua",
#          "nl": "Straatnaam",
#          "es": "Nombre de calle",
#          "it": "Nome strada",
#          "da": "Gadenavn",
#          "pl": "Nazwa ulicy",
#          "ro": "Nume strad\u0103",
#          "lt": "Gatv\u0117s pavadinimas",
#          "ja": "\u9053\u8def\u540d",
#          "lv": "Ielas nosaukums",
#          "ru": "\u041d\u0430\u0437\u0432\u0430\u043d\u0438\u0435 \u0443\u043b\u0438\u0446\u044b",
#          "he": "\u05e9\u05dd \u05e8\u05d7\u05d5\u05d1",
#          "ar": "\u0627\u0633\u0645 \u0627\u0644\u0634\u0627\u0631\u0639",
#          "cs": "N\u00e1zev ulice",
#          "hr": "Naziv ulice",
#          "ko": "\ub3c4\ub85c \uc774\ub984",
#          "sr": "Ime ulice",
#          "zh-hk": "\u8857\u9053\u540d\u7a31",
#          "vi": "T\u00ean \u0110\u01b0\u1eddng ph\u1ed1",
#          "fi": "Kadun nimi",
#          "sv": "Gatunamn",
#          "fr": "Nom de la rue",
#          "pt-pt": "Nome da Rua",
#          "el": "\u039f\u03b4\u03cc\u03c2",
#          "de": "Stra\u00dfenname"
#        },
#        "name": "Street Name"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "\u8ddd\u79bb\u6807\u8bb0",
#          "th": "\u0e08\u0e38\u0e14\u0e27\u0e31\u0e14\u0e23\u0e30\u0e22\u0e30\u0e17\u0e32\u0e07",
#          "nb": "Avstandsmerke",
#          "et": "Vahemaa t\u00e4his",
#          "tr": "Mesafe \u0130\u015faret\u00e7isi",
#          "zh-tw": "\u8ddd\u96e2\u6a19\u8a18",
#          "pt-br": "Marcador de Dist\u00e2ncia",
#          "nl": "Afstandsmarkering",
#          "es": "Marcador de distancia",
#          "it": "Marcatore distanze",
#          "da": "Afstandsmark\u00f8r",
#          "pl": "Znacznik odleg\u0142o\u015bci",
#          "ro": "Marcaj distan\u0163\u0103",
#          "lt": "Atstumo \u017eymeklis",
#          "ja": "\u8ddd\u96e2\u30de\u30fc\u30ab\u30fc",
#          "lv": "Distances mar\u0137ieris",
#          "ru": "\u0423\u043a\u0430\u0437\u0430\u0442\u0435\u043b\u044c \u0440\u0430\u0441\u0441\u0442\u043e\u044f\u043d\u0438\u044f",
#          "he": "\u05e1\u05de\u05df \u05de\u05e8\u05d7\u05e7",
#          "ar": "\u0639\u0644\u0627\u0645\u0629 \u0627\u0644\u0645\u0633\u0627\u0641\u0629",
#          "cs": "Zna\u010dka vzd\u00e1lenosti",
#          "hr": "Oznaka udaljenosti",
#          "ko": "\uac70\ub9ac \ud45c\uc9c0",
#          "sr": "Marker rastojanja",
#          "zh-hk": "\u8ddd\u96e2\u6a19\u8a18",
#          "vi": "\u0110\u00e1nh d\u1ea5u Kho\u1ea3ng c\u00e1ch",
#          "fi": "Et\u00e4isyysmerkitsin",
#          "sv": "Avst\u00e5ndsmark\u00f6r",
#          "fr": "Symbole ponctuel de distance",
#          "pt-pt": "Marcador de Dist\u00e2ncia",
#          "el": "\u0394\u03b5\u03af\u03ba\u03c4\u03b7\u03c2 \u03b1\u03c0\u03cc\u03c3\u03c4\u03b1\u03c3\u03b7\u03c2",
#          "de": "Entfernungsmarker"
#        },
#        "name": "Distance Marker"
#      }
#    ],
#    "name": "Address"
#  }, {
#    "localizedNames": {
#      "zh-cn": "\u90ae\u653f\u7f16\u7801",
#      "th": "\u0e23\u0e2b\u0e31\u0e2a\u0e44\u0e1b\u0e23\u0e29\u0e13\u0e35\u0e22\u0e4c",
#      "nb": "Post",
#      "et": "Postiaadress",
#      "tr": "Posta",
#      "zh-tw": "\u90f5\u905e\u5340\u865f",
#      "pt-br": "C\u00f3digo Postal",
#      "nl": "Postcode",
#      "es": "Postal",
#      "it": "Postale",
#      "da": "Postnummer",
#      "pl": "Pocztowy",
#      "ro": "Cod po\u015ftal",
#      "lt": "Pa\u0161to",
#      "ja": "\u90f5\u4fbf\u756a\u53f7",
#      "lv": "Pasts",
#      "ru": "\u041f\u043e\u0447\u0442\u043e\u0432\u044b\u0439",
#      "he": "\u05e9\u05dc \u05d3\u05d5\u05d0\u05e8",
#      "ar": "\u0628\u0631\u064a\u062f\u064a",
#      "cs": "Po\u0161tovn\u00ed",
#      "hr": "Po\u0161tanski broj",
#      "ko": "\uc6b0\ud3b8 \ubc88\ud638",
#      "sr": "Po\u0161tanski region",
#      "zh-hk": "\u90f5\u905e\u5340\u865f",
#      "vi": "B\u01b0u \u0111i\u1ec7n",
#      "fi": "Postinumero",
#      "sv": "Postnummer",
#      "fr": "Postal",
#      "pt-pt": "C\u00f3digo postal",
#      "el": "\u03a4\u03b1\u03c7\u03c5\u03b4\u03c1\u03bf\u03bc\u03b9\u03ba\u03ae",
#      "de": "Postalisch"
#    },
#    "categories": [
#      {
#        "localizedNames": {
#          "zh-cn": "\u4e3b\u8981\u90ae\u653f\u7f16\u7801",
#          "th": "\u0e23\u0e2b\u0e31\u0e2a\u0e44\u0e1b\u0e23\u0e13\u0e35\u0e22\u0e4c\u0e2b\u0e25\u0e31\u0e01",
#          "nb": "Prim\u00e6r poststed",
#          "et": "Peamine postiaadress",
#          "tr": "Birincil Posta Adresi",
#          "zh-tw": "\u4e3b\u8981\u90f5\u905e\u5340\u865f",
#          "pt-br": "Principal Postal",
#          "nl": "Primaire postcode",
#          "es": "Direcci\u00f3n postal principal",
#          "it": "Postale principale",
#          "da": "Prim\u00e6rt postnummer",
#          "pl": "Poczta g\u0142\u00f3wna",
#          "ro": "Cod po\u015ftal principal",
#          "lt": "Pagrindinis pa\u0161to kodas",
#          "ja": "\u57fa\u672c\u306e\u90f5\u4fbf\u756a\u53f7",
#          "lv": "Galvenais pasts",
#          "ru": "\u0413\u043b\u0430\u0432\u043d\u043e\u0435 \u043f\u043e\u0447\u0442\u043e\u0432\u043e\u0435 \u043e\u0442\u0434\u0435\u043b\u0435\u043d\u0438\u0435",
#          "he": "\u05d3\u05d5\u05d0\u05e8 \u05de\u05e8\u05db\u05d6\u05d9",
#          "ar": "\u0627\u0644\u0631\u0645\u0632 \u0627\u0644\u0628\u0631\u064a\u062f\u064a \u0627\u0644\u0623\u0633\u0627\u0633\u064a",
#          "cs": "Prim\u00e1rn\u00ed po\u0161tovn\u00ed",
#          "hr": "Primarni po\u0161tanski broj",
#          "ko": "\uae30\ubcf8 \uc6b0\ud3b8 \ubc88\ud638",
#          "sr": "Primarni po\u0161tanski region",
#          "zh-hk": "\u4e3b\u8981\u90f5\u905e\u5340\u865f",
#          "vi": "B\u01b0u \u0111i\u1ec7n Ch\u00ednh",
#          "fi": "Ensisijainen postinumero",
#          "sv": "Prim\u00e4rt postnummer",
#          "fr": "Nom postal principal",
#          "pt-pt": "C\u00f3digo Postal Prim\u00e1rio",
#          "el": "\u039a\u03cd\u03c1\u03b9\u03b1 \u03c4\u03b1\u03c7\u03c5\u03b4\u03c1\u03bf\u03bc\u03b9\u03ba\u03ae",
#          "de": "Prim\u00e4re Postanschrift"
#        },
#        "name": "Primary Postal"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "\u90ae\u653f\u5730\u70b9",
#          "th": "\u0e23\u0e2b\u0e31\u0e2a\u0e44\u0e1b\u0e23\u0e29\u0e13\u0e35\u0e22\u0e4c\u0e17\u0e49\u0e2d\u0e07\u0e16\u0e34\u0e48\u0e19",
#          "nb": "Poststed",
#          "et": "Postiaadressi asukoht",
#          "tr": "Posta B\u00f6lgesi",
#          "zh-tw": "\u90f5\u905e\u5340\u865f\u4f4d\u7f6e",
#          "pt-br": "Localidade do Postal",
#          "nl": "Postadres",
#          "es": "Distrito postal",
#          "it": "Localit\u00e0 postale",
#          "da": "Post-lokalitet",
#          "pl": "Lokalizacja poczty",
#          "ro": "Localitate po\u015ftal\u0103",
#          "lt": "Pa\u0161to kodo vietov\u0117",
#          "ja": "\u90f5\u4fbf\u5730\u533a",
#          "lv": "Pasta novietojums",
#          "ru": "\u041f\u043e\u0447\u0442\u043e\u0432\u043e\u0435 \u043c\u0435\u0441\u0442\u043e\u043f\u043e\u043b\u043e\u0436\u0435\u043d\u0438\u0435",
#          "he": "\u05d3\u05d5\u05d0\u05e8 \u05de\u05e7\u05d5\u05de\u05d9",
#          "ar": "\u0627\u0644\u0645\u0646\u0637\u0642\u0629 \u0627\u0644\u0628\u0631\u064a\u062f\u064a\u0629",
#          "cs": "Po\u0161tovn\u00ed lokalita",
#          "hr": "Lokalitet po\u0161tanskog broja",
#          "ko": "\uc6b0\ud3b8 \ubc88\ud638 \uc9c0\uc5ed \ucf54\ub4dc",
#          "sr": "Lokalitet po\u0161tanskog regiona",
#          "zh-hk": "\u90f5\u905e\u5340\u865f\u4f4d\u7f6e",
#          "vi": "B\u01b0u \u0111i\u1ec7n \u0110\u1ecba ph\u01b0\u01a1ng",
#          "fi": "Postinumero ja postitoimipaikka",
#          "sv": "Postnumrets plats",
#          "fr": "Localit\u00e9 postale",
#          "pt-pt": "Localidade Postal",
#          "el": "\u03a4\u03b1\u03c7\u03c5\u03b4\u03c1\u03bf\u03bc\u03b9\u03ba\u03ae \u03c4\u03bf\u03c0\u03bf\u03b8\u03b5\u03c3\u03af\u03b1",
#          "de": "Postalischer Bestimmungsort"
#        },
#        "name": "Postal Locality"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "\u90ae\u653f\u7f16\u7801\u6269\u5c55",
#          "th": "\u0e23\u0e2b\u0e31\u0e2a\u0e44\u0e1b\u0e23\u0e13\u0e35\u0e22\u0e4c\u0e40\u0e2a\u0e23\u0e34\u0e21",
#          "nb": "Utvidet postnummer",
#          "et": "Postiindeks",
#          "tr": "Posta Uzant\u0131s\u0131",
#          "zh-tw": "\u90f5\u905e\u5340\u865f\u5ef6\u4f38",
#          "pt-br": "Extens\u00e3o do Postal",
#          "nl": "Uitbreiding van postadres",
#          "es": "Extensi\u00f3n postal",
#          "it": "Estensione postale",
#          "da": "Post-udstr\u00e6kning",
#          "pl": "Kod pocztowy",
#          "ro": "Extensie po\u015ftal\u0103",
#          "lt": "Pa\u0161to kodo pl\u0117tinys",
#          "ja": "\u8ffd\u52a0\u306e\u90f5\u4fbf\u756a\u53f7",
#          "lv": "Pasta papla\u0161in\u0101jums",
#          "ru": "\u0414\u043e\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0435 \u043e\u0442\u0434\u0435\u043b\u0435\u043d\u0438\u0435",
#          "he": "\u05e9\u05dc\u05d5\u05d7\u05ea \u05d3\u05d5\u05d0\u05e8",
#          "ar": "\u0627\u0644\u0627\u0645\u062a\u062f\u0627\u062f \u0627\u0644\u0628\u0631\u064a\u062f\u064a",
#          "cs": "Po\u0161tovn\u00ed roz\u0161\u00ed\u0159en\u00ed",
#          "hr": "Ekstenzija po\u0161tanskog broja",
#          "ko": "\uc6b0\ud3b8 \ubc88\ud638 \ud655\uc7a5 \ucf54\ub4dc",
#          "sr": "Pro\u0161irenje po\u0161tanskog regiona",
#          "zh-hk": "\u90f5\u905e\u5340\u865f\u5ef6\u4f38",
#          "vi": "M\u1edf r\u1ed9ng B\u01b0u \u0111i\u1ec7n",
#          "fi": "Postinumeron tarkenne",
#          "sv": "Ut\u00f6kat postnummer",
#          "fr": "Extension postale",
#          "pt-pt": "Extens\u00e3o Postal",
#          "el": "\u03a4\u03b1\u03c7\u03c5\u03b4\u03c1\u03bf\u03bc\u03b9\u03ba\u03ae \u03b5\u03c0\u03ad\u03ba\u03c4\u03b1\u03c3\u03b7",
#          "de": "Erweiterung der Postanschrift"
#        },
#        "name": "Postal Extension"
#      }
#    ],
#    "name": "Postal"
#  }, {
#    "localizedNames": {
#      "zh-cn": "\u5750\u6807\u7cfb",
#      "th": "\u0e23\u0e30\u0e1a\u0e1a\u0e1e\u0e34\u0e01\u0e31\u0e14",
#      "nb": "Koordinatsystem",
#      "et": "Koordinaats\u00fcsteem",
#      "tr": "Koordinat Sistemi",
#      "zh-tw": "\u5ea7\u6a19\u7cfb\u7d71",
#      "pt-br": "Sistema de Coordenadas",
#      "nl": "Co\u00f6rdinatensysteem",
#      "es": "Sistema de coordenadas",
#      "it": "Sistema di coordinate",
#      "da": "Koordinatsystem",
#      "pl": "Uk\u0142ad wsp\u00f3\u0142rz\u0119dnych",
#      "ro": "Sistem de coordonate",
#      "lt": "Koordina\u010di\u0173 sistema",
#      "ja": "\u5ea7\u6a19\u7cfb",
#      "lv": "Koordin\u0113\u0161anas sist\u0113ma",
#      "ru": "\u0421\u0438\u0441\u0442\u0435\u043c\u0430 \u043a\u043e\u043e\u0440\u0434\u0438\u043d\u0430\u0442",
#      "he": "\u05de\u05e2\u05e8\u05db\u05ea \u05e7\u05d5\u05d0\u05d5\u05e8\u05d3\u05d9\u05e0\u05d8\u05d5\u05ea",
#      "ar": "\u0627\u0644\u0646\u0638\u0627\u0645 \u0627\u0644\u0625\u062d\u062f\u0627\u062b\u064a",
#      "cs": "Sou\u0159adnicov\u00fd syst\u00e9m",
#      "hr": "Koordinatni sustav",
#      "ko": "\uc88c\ud45c \uccb4\uacc4",
#      "sr": "Koordinatni sistem",
#      "zh-hk": "\u5ea7\u6a19\u7cfb\u7d71",
#      "vi": "H\u1ec7 T\u1ecda \u0111\u1ed9",
#      "fi": "Koordinaattij\u00e4rjestelm\u00e4",
#      "sv": "Koordinatsystem",
#      "fr": "Syst\u00e8me de coordonn\u00e9es",
#      "pt-pt": "Sistema de Coordenadas",
#      "el": "\u03a3\u03cd\u03c3\u03c4\u03b7\u03bc\u03b1 \u03c3\u03c5\u03bd\u03c4\u03b5\u03c4\u03b1\u03b3\u03bc\u03ad\u03bd\u03c9\u03bd",
#      "de": "Koordinatensystem"
#    },
#    "categories": [
#      {
#        "localizedNames": {
#          "zh-cn": "\u7ecf\u7eac\u5ea6",
#          "th": "\u0e25\u0e30\u0e15\u0e34\u0e08\u0e39\u0e14/\u0e25\u0e2d\u0e07\u0e08\u0e34\u0e08\u0e39\u0e14",
#          "nb": "LatLong",
#          "et": "Laius- ja pikkuskraad",
#          "tr": "Enlem ve Boylam",
#          "zh-tw": "LatLong",
#          "pt-br": "LatLong",
#          "nl": "Breedtegraad/lengtegraad",
#          "es": "LatLong",
#          "it": "Lat/Long",
#          "da": "BreL\u00e6ng",
#          "pl": "Szer. i d\u0142. geogr.",
#          "ro": "LatLong",
#          "lt": "LatLong",
#          "ja": "\u7d4c\u7def\u5ea6",
#          "lv": "LatLong",
#          "ru": "\u0428\u0438\u0440\u043e\u0442\u0430\u0414\u043e\u043b\u0433\u043e\u0442\u0430",
#          "he": "\u05d0\u05d5\u05e8\u05da \u05e8\u05d5\u05d7\u05d1",
#          "ar": "LatLong",
#          "cs": "Zem\u011bpisn\u00e1 \u0161\u00ed\u0159ka, d\u00e9lka",
#          "hr": "\u0160ir./Du\u017e.",
#          "ko": "LatLong",
#          "sr": "\u0160irinaDu\u017eina",
#          "zh-hk": "LatLong",
#          "vi": "Kinh V\u0129 \u0111\u1ed9",
#          "fi": "LevPit",
#          "sv": "LatLong",
#          "fr": "LatLong",
#          "pt-pt": "LatLong",
#          "el": "\u0393\u03b5\u03c9\u03b3\u03c1. \u03c0\u03bb\u03ac\u03c4\u03bf\u03c2/\u03bc\u03ae\u03ba\u03bf\u03c2",
#          "de": "LatLong"
#        },
#        "name": "LatLong"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "MGRS",
#          "th": "MGRS",
#          "nb": "MGRS",
#          "et": "MGRS",
#          "tr": "MGRS",
#          "zh-tw": "MGRS",
#          "pt-br": "MGRS",
#          "nl": "MGRS",
#          "es": "MGRS",
#          "it": "MGRS",
#          "da": "MGRS",
#          "pl": "MGRS",
#          "ro": "MGRS",
#          "lt": "MGRS",
#          "ja": "MGRS",
#          "lv": "MGRS",
#          "ru": "MGRS",
#          "he": "MGRS",
#          "ar": "MGRS",
#          "cs": "Vojensk\u00e1 hl\u00e1sn\u00e1 s\u00ed\u0165 (MGRS)",
#          "hr": "MGRS",
#          "ko": "MGRS",
#          "sr": "MGRS",
#          "zh-hk": "MGRS",
#          "vi": "MGRS",
#          "fi": "MGRS",
#          "sv": "MGRS",
#          "fr": "MGRS",
#          "pt-pt": "MGRS",
#          "el": "MGRS",
#          "de": "MGRS"
#        },
#        "name": "MGRS"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "XY",
#          "th": "XY",
#          "nb": "XY",
#          "et": "XY",
#          "tr": "XY",
#          "zh-tw": "XY",
#          "pt-br": "XY",
#          "nl": "XY",
#          "es": "XY",
#          "it": "XY",
#          "da": "XY",
#          "pl": "XY",
#          "ro": "XY",
#          "lt": "XY",
#          "ja": "XY",
#          "lv": "XY",
#          "ru": "XY",
#          "he": "XY",
#          "ar": "XY",
#          "cs": "XY",
#          "hr": "XY",
#          "ko": "XY",
#          "sr": "XY",
#          "zh-hk": "XY",
#          "vi": "XY",
#          "fi": "XY",
#          "sv": "XY",
#          "fr": "XY",
#          "pt-pt": "XY",
#          "el": "XY",
#          "de": "XY"
#        },
#        "name": "XY"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "YX",
#          "th": "YX",
#          "nb": "YX",
#          "et": "YX",
#          "tr": "YX",
#          "zh-tw": "YX",
#          "pt-br": "YX",
#          "nl": "YX",
#          "es": "YX",
#          "it": "YX",
#          "da": "YX",
#          "pl": "YX",
#          "ro": "YX",
#          "lt": "YX",
#          "ja": "YX",
#          "lv": "YX",
#          "ru": "YX",
#          "he": "YX",
#          "ar": "YX",
#          "cs": "YX",
#          "hr": "YX",
#          "ko": "YX",
#          "sr": "YX",
#          "zh-hk": "YX",
#          "vi": "YX",
#          "fi": "YX",
#          "sv": "YX",
#          "fr": "YX",
#          "pt-pt": "YX",
#          "el": "YX",
#          "de": "YX"
#        },
#        "name": "YX"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "USNG",
#          "th": "USNG",
#          "nb": "USNG",
#          "et": "USNG",
#          "tr": "USNG",
#          "zh-tw": "USNG",
#          "pt-br": "USNG",
#          "nl": "USNG",
#          "es": "USNG",
#          "it": "USNG",
#          "da": "USNG",
#          "pl": "USNG",
#          "ro": "USNG",
#          "lt": "USNG",
#          "ja": "USNG",
#          "lv": "USNG",
#          "ru": "USNG",
#          "he": "USNG",
#          "ar": "USNG",
#          "cs": "USNG",
#          "hr": "USNG",
#          "ko": "USNG",
#          "sr": "USNG",
#          "zh-hk": "USNG",
#          "vi": "USNG",
#          "fi": "USNG",
#          "sv": "USNG",
#          "fr": "USNG",
#          "pt-pt": "USNG",
#          "el": "USNG",
#          "de": "USNG"
#        },
#        "name": "USNG"
#      }
#    ],
#    "name": "Coordinate System"
#  }, {
#    "localizedNames": {
#      "zh-cn": "\u5c45\u6c11\u533a",
#      "th": "\u0e2a\u0e16\u0e32\u0e19\u0e17\u0e35\u0e48\u0e17\u0e35\u0e48\u0e21\u0e35\u0e1b\u0e23\u0e30\u0e0a\u0e32\u0e01\u0e23",
#      "nb": "Befolket sted",
#      "et": "Asustatud koht",
#      "tr": "Kalabal\u0131k Yer",
#      "zh-tw": "\u805a\u5c45\u5730",
#      "pt-br": "Lugar Ocupado",
#      "nl": "Bevolkt gebied",
#      "es": "Lugar poblado",
#      "it": "Zona abitata",
#      "da": "Beboet omr\u00e5de",
#      "pl": "Miejsce zamieszkane",
#      "ro": "Loc populat",
#      "lt": "Apgyvendinta vieta",
#      "ja": "\u5c45\u4f4f\u533a",
#      "lv": "Apdz\u012bvota vieta",
#      "ru": "\u041d\u0430\u0441\u0435\u043b\u0435\u043d\u043d\u044b\u0439 \u043f\u0443\u043d\u043a\u0442",
#      "he": "\u05de\u05e7\u05d5\u05dd \u05de\u05d9\u05d5\u05e9\u05d1",
#      "ar": "\u0627\u0644\u0623\u0645\u0627\u0643\u0646 \u0627\u0644\u0645\u0639\u0645\u0648\u0631\u0629 \u0628\u0627\u0644\u0633\u0643\u0627\u0646",
#      "cs": "Obydlen\u00e9 m\u00edsto",
#      "hr": "Naseljeno mjesto",
#      "ko": "\uac70\uc8fc \uc9c0\uc5ed",
#      "sr": "Naseljeno mesto",
#      "zh-hk": "\u805a\u5c45\u5730",
#      "vi": "N\u01a1i \u0111\u00f4ng d\u00e2n",
#      "fi": "Asuinalue",
#      "sv": "Bebodd plats",
#      "fr": "Lieu peupl\u00e9",
#      "pt-pt": "Povoa\u00e7\u00e3o",
#      "el": "\u039a\u03b1\u03c4\u03bf\u03b9\u03ba\u03b7\u03bc\u03ad\u03bd\u03b7 \u03c0\u03b5\u03c1\u03b9\u03bf\u03c7\u03ae",
#      "de": "Besiedelter Ort"
#    },
#    "categories": [
#      {
#        "localizedNames": {
#          "zh-cn": "\u4f4f\u5b85\u533a",
#          "th": "\u0e1a\u0e23\u0e34\u0e40\u0e27\u0e13\u0e43\u0e01\u0e25\u0e49\u0e40\u0e04\u0e35\u0e22\u0e07",
#          "nb": "Nabolag",
#          "et": "Linnaosa",
#          "tr": "Kom\u015fu",
#          "zh-tw": "\u8857\u5340",
#          "pt-br": "Bairro",
#          "nl": "Omgeving",
#          "es": "Barrio",
#          "it": "Vicinato",
#          "da": "Lokalomr\u00e5de",
#          "pl": "Dzielnica",
#          "ro": "Cartier",
#          "lt": "Apylink\u0117",
#          "ja": "\u8fd1\u90ca",
#          "lv": "Apk\u0101rtne",
#          "ru": "\u0420\u0430\u0439\u043e\u043d",
#          "he": "\u05e9\u05db\u05d5\u05e0\u05d4",
#          "ar": "\u0645\u062c\u0627\u0648\u0631\u0629",
#          "cs": "\u010ctvr\u0165",
#          "hr": "\u010cetvrt",
#          "ko": "\ub124\uc774\ubc84\ud6c4\ub4dc",
#          "sr": "Susedstvo",
#          "zh-hk": "\u8857\u5340",
#          "vi": "V\u00f9ng l\u00e2n c\u1eadn",
#          "fi": "Kaupunginosa",
#          "sv": "Grannskap",
#          "fr": "Quartier",
#          "pt-pt": "Bairro",
#          "el": "\u0393\u03b5\u03b9\u03c4\u03bf\u03bd\u03b9\u03ac",
#          "de": "Nachbarschaft"
#        },
#        "name": "Neighborhood"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "\u57ce\u5e02",
#          "th": "\u0e40\u0e21\u0e37\u0e2d\u0e07",
#          "nb": "Poststed",
#          "et": "Linn",
#          "tr": "\u015eehir",
#          "zh-tw": "\u5e02",
#          "pt-br": "Cidade",
#          "nl": "Plaats",
#          "es": "Ciudad",
#          "it": "Citt\u00e0",
#          "da": "By",
#          "pl": "Miasto",
#          "ro": "Ora\u015f",
#          "lt": "Miestas",
#          "ja": "\u90fd\u5e02",
#          "lv": "Pils\u0113ta",
#          "ru": "\u0413\u043e\u0440\u043e\u0434",
#          "he": "\u05e2\u05d9\u05e8",
#          "ar": "\u0645\u062f\u064a\u0646\u0629",
#          "cs": "M\u011bsto",
#          "hr": "Grad",
#          "ko": "\ub3c4\uc2dc",
#          "sr": "Grad",
#          "zh-hk": "\u5e02",
#          "vi": "Th\u00e0nh ph\u1ed1",
#          "fi": "Kaupunki",
#          "sv": "Ort",
#          "fr": "Ville",
#          "pt-pt": "Cidade",
#          "el": "\u03a0\u03cc\u03bb\u03b7",
#          "de": "Stadt"
#        },
#        "name": "City"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "\u4e9a\u533a",
#          "th": "\u0e20\u0e39\u0e21\u0e34\u0e20\u0e32\u0e04\u0e22\u0e48\u0e2d\u0e22",
#          "nb": "Underregion",
#          "et": "Alampiirkond",
#          "tr": "Alt B\u00f6lge",
#          "zh-tw": "\u4e9e\u5340",
#          "pt-br": "Subregi\u00e3o",
#          "nl": "Subregio",
#          "es": "Subregi\u00f3n",
#          "it": "Sottoregione",
#          "da": "Underregion",
#          "pl": "Podregion",
#          "ro": "Subregiune",
#          "lt": "Paregionis",
#          "ja": "\u5c0f\u533a\u57df",
#          "lv": "Apak\u0161re\u0123ions",
#          "ru": "\u0420\u0435\u0433\u0438\u043e\u043d",
#          "he": "\u05ea\u05ea-\u05d0\u05d6\u05d5\u05e8",
#          "ar": "\u0645\u0646\u0637\u0642\u0629 \u0641\u0631\u0639\u064a\u0629",
#          "cs": "Sp\u00e1dov\u00e1 oblast",
#          "hr": "Podregija",
#          "ko": "\uc74d/\uba74/\ub3d9",
#          "sr": "Podregion",
#          "zh-hk": "\u4e9e\u5340",
#          "vi": "Ti\u1ec3u v\u00f9ng",
#          "fi": "Osa-alue",
#          "sv": "Underregion",
#          "fr": "Sous-r\u00e9gion",
#          "pt-pt": "Sub-regi\u00e3o",
#          "el": "\u03a5\u03c0\u03bf\u03c0\u03b5\u03c1\u03b9\u03bf\u03c7\u03ae",
#          "de": "Subregion"
#        },
#        "name": "Subregion"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "\u5730\u533a",
#          "th": "\u0e20\u0e39\u0e21\u0e34\u0e20\u0e32\u0e04",
#          "nb": "Region",
#          "et": "Piirkond",
#          "tr": "B\u00f6lge",
#          "zh-tw": "\u5730\u5340",
#          "pt-br": "Regi\u00e3o",
#          "nl": "Regio",
#          "es": "Regi\u00f3n",
#          "it": "Regione",
#          "da": "Region",
#          "pl": "Region",
#          "ro": "Regiune",
#          "lt": "Regionas",
#          "ja": "\u5730\u57df",
#          "lv": "Re\u0123ions",
#          "ru": "\u0420\u0435\u0433\u0438\u043e\u043d",
#          "he": "\u05d0\u05d9\u05d6\u05d5\u05e8",
#          "ar": "\u0627\u0644\u0645\u0646\u0637\u0642\u0629",
#          "cs": "Region",
#          "hr": "Regija",
#          "ko": "\uc9c0\uc5ed",
#          "sr": "Region",
#          "zh-hk": "\u5730\u5340",
#          "vi": "V\u00f9ng",
#          "fi": "Alue",
#          "sv": "Region",
#          "fr": "R\u00e9gion",
#          "pt-pt": "Regi\u00e3o",
#          "el": "\u03a0\u03b5\u03c1\u03b9\u03bf\u03c7\u03ae",
#          "de": "Region"
#        },
#        "name": "Region"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "\u56fd\u5bb6",
#          "th": "\u0e1b\u0e23\u0e30\u0e40\u0e17\u0e28",
#          "nb": "Land",
#          "et": "Riik",
#          "tr": "\u00dclke",
#          "zh-tw": "\u570b\u5bb6",
#          "pt-br": "Pa\u00eds",
#          "nl": "Land",
#          "es": "Pa\u00eds",
#          "it": "Paese",
#          "da": "Land",
#          "pl": "Kraj",
#          "ro": "\u0162ar\u0103",
#          "lt": "\u0160alis",
#          "ja": "\u56fd",
#          "lv": "Valsts",
#          "ru": "\u041e\u043a\u0440\u0443\u0433",
#          "he": "\u05d0\u05e8\u05e5",
#          "ar": "\u0628\u0644\u062f",
#          "cs": "Zem\u011b",
#          "hr": "Zemlja",
#          "ko": "\uad6d\uac00",
#          "sr": "Zemlja",
#          "zh-hk": "\u570b\u5bb6",
#          "vi": "Qu\u1ed1c gia",
#          "fi": "Maa",
#          "sv": "Land",
#          "fr": "Pays",
#          "pt-pt": "Pa\u00eds",
#          "el": "\u03a7\u03ce\u03c1\u03b1",
#          "de": "Land"
#        },
#        "name": "Country"
#      },
#      {
#        "localizedNames": {
#          "zh-cn": "\u533a\u57df",
#          "th": "\u0e42\u0e0b\u0e19",
#          "nb": "Sone",
#          "et": "Tsoon",
#          "tr": "B\u00f6lge",
#          "zh-tw": "\u5340\u57df",
#          "pt-br": "Zona",
#          "nl": "Zone",
#          "es": "Zona",
#          "it": "Zona",
#          "da": "Zone",
#          "pl": "Strefa",
#          "ro": "Zon\u0103",
#          "lt": "Sritis",
#          "ja": "\u30be\u30fc\u30f3",
#          "lv": "Josla",
#          "ru": "\u0417\u043e\u043d\u0430",
#          "he": "\u05d0\u05d6\u05d5\u05e8",
#          "ar": "\u0645\u0646\u0637\u0642\u0629",
#          "cs": "Z\u00f3na",
#          "hr": "Zona",
#          "ko": "\uad6c\uc5ed",
#          "sr": "Zona",
#          "zh-hk": "\u5340\u57df",
#          "vi": "Khu v\u1ef1c",
#          "fi": "Kaista",
#          "sv": "Zon",
#          "fr": "Zone",
#          "pt-pt": "Zona",
#          "el": "\u0396\u03ce\u03bd\u03b7",
#          "de": "Zone"
#        },
#        "name": "Zone"
#      }
#    ],
#    "name": "Populated Place"
#  }, {
#    "localizedNames": {
#      "zh-cn": "POI",
#      "th": "\u0e08\u0e38\u0e14\u0e17\u0e35\u0e48\u0e2a\u0e19\u0e43\u0e08",
#      "nb": "POI",
#      "et": "POI",
#      "tr": "POI",
#      "zh-tw": "POI",
#      "pt-br": "POI",
#      "nl": "NP",
#      "es": "POI",
#      "it": "Punto di interesse",
#      "da": "IP",
#      "pl": "POI",
#      "ro": "PDI",
#      "lt": "Lankytinos vietos",
#      "ja": "POI",
#      "lv": "IP",
#      "ru": "POI (\u0442\u043e\u0447\u043a\u0430 \u0438\u043d\u0442\u0435\u0440\u0435\u0441\u0430)",
#      "he": "\u05e0\u05e7\u05d5\u05d3\u05ea \u05e2\u05e0\u05d9\u05d9\u05df",
#      "ar": "POI",
#      "cs": "POI",
#      "hr": "ZL",
#      "ko": "POI",
#      "sr": "POI",
#      "zh-hk": "POI",
#      "vi": "POI",
#      "fi": "POI",
#      "sv": "POI",
#      "fr": "PI",
#      "pt-pt": "POI",
#      "el": "POI",
#      "de": "POI"
#    },
#    "categories": [
#      {
#        "localizedNames": {
#          "zh-cn": "\u827a\u672f\u548c\u5a31\u4e50",
#          "th": "\u0e28\u0e34\u0e25\u0e1b\u0e30\u0e41\u0e25\u0e30\u0e01\u0e32\u0e23\u0e41\u0e2a\u0e14\u0e07",
#          "nb": "Kultur og underholdning",
#          "et": "Kunst ja meelelahutus",
#          "tr": "G\u00fczel Sanatlar ve E\u011flence",
#          "zh-tw": "\u85dd\u8853\u8207\u5a1b\u6a02",
#          "pt-br": "Artes e Entretenimento",
#          "nl": "Kunst en amusement",
#          "es": "Arte y ocio",
#          "it": "Arte e intrattenimento",
#          "da": "Kunst og underholdning",
#          "pl": "Rozrywka i sztuka",
#          "ro": "Arte \u015fi divertisment",
#          "lt": "Menas ir pramogos",
#          "ja": "\u30a2\u30fc\u30c8/\u30a8\u30f3\u30bf\u30fc\u30c6\u30a4\u30e1\u30f3\u30c8",
#          "lv": "M\u0101ksla un izklaide",
#          "ru": "\u0418\u0441\u043a\u0443\u0441\u0441\u0442\u0432\u043e \u0438 \u0440\u0430\u0437\u0432\u043b\u0435\u0447\u0435\u043d\u0438\u044f",
#          "he": "\u05d0\u05d5\u05de\u05e0\u05d5\u05ea \u05d5\u05d1\u05d9\u05d3\u05d5\u05e8",
#          "ar": "\u0641\u0646\u0648\u0646 \u0648\u062a\u0631\u0641\u064a\u0647",
#          "cs": "Um\u011bn\u00ed a z\u00e1bava",
#          "hr": "Umjetnost i zabava",
#          "ko": "\uc608\uc220 \ubc0f \uc5d4\ud130\ud14c\uc778\uba3c\ud2b8",
#          "sr": "Umetnost i zabava",
#          "zh-hk": "\u85dd\u8853\u8207\u5a1b\u6a02",
#          "vi": "Ngh\u1ec7 thu\u1eadt v\u00e0 Gi\u1ea3i tr\u00ed",
#          "fi": "Taide ja viihde",
#          "sv": "Kultur och underh\u00e5llning",
#          "fr": "Arts et loisirs",
#          "pt-pt": "Artes e Entretenimento",
#          "el": "\u03a4\u03ad\u03c7\u03bd\u03b5\u03c2 \u03ba\u03b1\u03b9 \u03a8\u03c5\u03c7\u03b1\u03b3\u03c9\u03b3\u03af\u03b1",
#          "de": "Kunst und Unterhaltung"
#        },
#        "categories": [
#          {
#            "localizedNames": {
#              "zh-cn": "\u6e38\u4e50\u573a",
#              "th": "\u0e2a\u0e27\u0e19\u0e2a\u0e19\u0e38\u0e01",
#              "nb": "Forn\u00f8yelsespark",
#              "et": "L\u00f5bustuspark",
#              "tr": "E\u011flence Park\u0131",
#              "zh-tw": "\u904a\u6a02\u5834",
#              "pt-br": "Parque de Divers\u00e3o",
#              "nl": "Pretpark",
#              "es": "Parque de atracciones",
#              "it": "Parco di divertimenti",
#              "da": "Forlystelsespark",
#              "pl": "Weso\u0142e miasteczko",
#              "ro": "Parc de distrac\u0163ii",
#              "lt": "Nuotyki\u0173 parkas",
#              "ja": "\u904a\u5712\u5730",
#              "lv": "Izpriecu parks",
#              "ru": "\u041f\u0430\u0440\u043a \u0440\u0430\u0437\u0432\u043b\u0435\u0447\u0435\u043d\u0438\u0439",
#              "he": "\u05e4\u05d0\u05e8\u05e7 \u05e9\u05e2\u05e9\u05d5\u05e2\u05d9\u05dd",
#              "ar": "\u0645\u062a\u0646\u0632\u0647 \u062a\u0631\u0641\u064a\u0647\u064a",
#              "cs": "Z\u00e1bavn\u00ed park",
#              "hr": "Zabavni park",
#              "ko": "\ub180\uc774 \uacf5\uc6d0",
#              "sr": "Zabavni park",
#              "zh-hk": "\u904a\u6a02\u5834",
#              "vi": "C\u00f4ng vi\u00ean Gi\u1ea3i tr\u00ed",
#              "fi": "Huvipuisto",
#              "sv": "N\u00f6jesf\u00e4lt",
#              "fr": "Parc d'attractions",
#              "pt-pt": "Parque de Divers\u00f5es",
#              "el": "\u03a0\u03ac\u03c1\u03ba\u03bf \u03c8\u03c5\u03c7\u03b1\u03b3\u03c9\u03b3\u03af\u03b1\u03c2",
#              "de": "Vergn\u00fcgungspark"
#            },
#            "name": "Amusement Park"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u6c34\u65cf\u9986",
#              "th": "\u0e1e\u0e34\u0e1e\u0e34\u0e18\u0e20\u0e31\u0e13\u0e11\u0e4c\u0e2a\u0e31\u0e15\u0e27\u0e4c\u0e19\u0e49\u0e33",
#              "nb": "Akvarium",
#              "et": "Akvaarium",
#              "tr": "Akvaryum",
#              "zh-tw": "\u6c34\u65cf\u9928",
#              "pt-br": "Aqu\u00e1rio",
#              "nl": "Aquarium",
#              "es": "Acuario",
#              "it": "Acquario",
#              "da": "Akvarium",
#              "pl": "Akwarium",
#              "ro": "Acvariu",
#              "lt": "Akvariumas",
#              "ja": "\u6c34\u65cf\u9928",
#              "lv": "Akv\u0101rijs",
#              "ru": "\u0410\u043a\u0432\u0430\u0440\u0438\u0443\u043c",
#              "he": "\u05d0\u05e7\u05d5\u05d5\u05e8\u05d9\u05d5\u05dd",
#              "ar": "\u062d\u0648\u0636 \u0633\u0645\u0643",
#              "cs": "Akv\u00e1rium",
#              "hr": "Akvarij",
#              "ko": "\uc218\uc871\uad00",
#              "sr": "Akvarijum",
#              "zh-hk": "\u6c34\u65cf\u9928",
#              "vi": "Th\u1ee7y cung",
#              "fi": "Akvaario",
#              "sv": "Akvarium",
#              "fr": "Aquarium",
#              "pt-pt": "Aqu\u00e1rio",
#              "el": "\u0395\u03bd\u03c5\u03b4\u03c1\u03b5\u03af\u03bf",
#              "de": "Aquarium"
#            },
#            "name": "Aquarium"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u7f8e\u672f\u9986",
#              "th": "\u0e2d\u0e32\u0e23\u0e4c\u0e15\u0e41\u0e01\u0e25\u0e2d\u0e23\u0e35",
#              "nb": "Kunstgalleri",
#              "et": "Kunstigalerii",
#              "tr": "Resim Galerisi",
#              "zh-tw": "\u85dd\u5eca",
#              "pt-br": "Galeria de Arte",
#              "nl": "Kunstgalerie",
#              "es": "Galer\u00eda de arte",
#              "it": "Galleria d'arte",
#              "da": "Kunstgalleri",
#              "pl": "Galeria sztuki",
#              "ro": "Galerie de art\u0103",
#              "lt": "Meno galerija",
#              "ja": "\u30a2\u30fc\u30c8 \u30ae\u30e3\u30e9\u30ea\u30fc",
#              "lv": "M\u0101kslas galerija",
#              "ru": "\u0425\u0443\u0434\u043e\u0436\u0435\u0441\u0442\u0432\u0435\u043d\u043d\u0430\u044f \u0433\u0430\u043b\u0435\u0440\u0435\u044f",
#              "he": "\u05d2\u05dc\u05e8\u05d9\u05d4 \u05dc\u05d0\u05d5\u05de\u05e0\u05d5\u05ea",
#              "ar": "\u0645\u0639\u0631\u0636 \u0627\u0644\u0641\u0646\u0648\u0646",
#              "cs": "Galerie um\u011bn\u00ed",
#              "hr": "Umjetni\u010dka galerija",
#              "ko": "\ubbf8\uc220\uad00",
#              "sr": "Umetni\u010dka galerija",
#              "zh-hk": "\u85dd\u5eca",
#              "vi": "Tri\u1ec3n l\u00e3m Ngh\u1ec7 thu\u1eadt",
#              "fi": "Taidegalleria",
#              "sv": "Konstgalleri",
#              "fr": "Galerie d\\'art",
#              "pt-pt": "Galeria de Arte",
#              "el": "\u0393\u03ba\u03b1\u03bb\u03b5\u03c1\u03af \u03c4\u03ad\u03c7\u03bd\u03b7\u03c2",
#              "de": "Kunstgalerie"
#            },
#            "name": "Art Gallery"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u827a\u672f\u535a\u7269\u9986",
#              "th": "\u0e1e\u0e34\u0e1e\u0e34\u0e18\u0e20\u0e31\u0e13\u0e11\u0e4c\u0e28\u0e34\u0e25\u0e1b\u0e30",
#              "nb": "Kunstmuseum",
#              "et": "Kunstimuuseum",
#              "tr": "Sanat M\u00fczesi",
#              "zh-tw": "\u85dd\u8853\u535a\u7269\u9928",
#              "pt-br": "Museu de Arte",
#              "nl": "Kunstmuseum",
#              "es": "Museo de arte",
#              "it": "Museo d'arte",
#              "da": "Kunstmuseum",
#              "pl": "Muzeum sztuki",
#              "ro": "Muzeu de art\u0103",
#              "lt": "Meno muziejus",
#              "ja": "\u7f8e\u8853\u9928",
#              "lv": "M\u0101kslas muzejs",
#              "ru": "\u0425\u0443\u0434\u043e\u0436\u0435\u0441\u0442\u0432\u0435\u043d\u043d\u044b\u0439 \u043c\u0443\u0437\u0435\u0439",
#              "he": "\u05de\u05d5\u05d6\u05d9\u05d0\u05d5\u05df \u05dc\u05d0\u05d5\u05de\u05e0\u05d5\u05ea",
#              "ar": "\u0645\u062a\u062d\u0641 \u0627\u0644\u0641\u0646\u0648\u0646",
#              "cs": "Muzeum um\u011bn\u00ed",
#              "hr": "Umjetni\u010dki muzej",
#              "ko": "\ubbf8\uc220 \ubc15\ubb3c\uad00",
#              "sr": "Umetni\u010dki muzej",
#              "zh-hk": "\u85dd\u8853\u535a\u7269\u9928",
#              "vi": "B\u1ea3o t\u00e0ng Ngh\u1ec7 thu\u1eadt",
#              "fi": "Taidemuseo",
#              "sv": "Konstmuseum",
#              "fr": "Mus\u00e9e d\\'art",
#              "pt-pt": "Museu de Arte",
#              "el": "\u039c\u03bf\u03c5\u03c3\u03b5\u03af\u03bf \u03c4\u03ad\u03c7\u03bd\u03b7\u03c2",
#              "de": "Kunstmuseum"
#            },
#            "name": "Art Museum"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u53f0\u7403\u5ba4",
#              "th": "\u0e1a\u0e34\u0e25\u0e40\u0e25\u0e35\u0e22\u0e14",
#              "nb": "Biljard",
#              "et": "Piljard",
#              "tr": "Bilardo",
#              "zh-tw": "\u649e\u7403",
#              "pt-br": "Bilhar",
#              "nl": "Biljartclub",
#              "es": "Billares",
#              "it": "Biliardi",
#              "da": "Billiard",
#              "pl": "Bilard",
#              "ro": "Biliard",
#              "lt": "Biliardas",
#              "ja": "\u30d3\u30ea\u30e4\u30fc\u30c9",
#              "lv": "Biljards",
#              "ru": "\u0411\u0438\u043b\u044c\u044f\u0440\u0434\u043d\u0430\u044f",
#              "he": "\u05d1\u05d9\u05dc\u05d9\u05d0\u05e8\u05d3",
#              "ar": "\u0628\u0644\u064a\u0627\u0631\u062f\u0648",
#              "cs": "Kule\u010dn\u00edk",
#              "hr": "Biljar",
#              "ko": "\ub2f9\uad6c\uc7a5",
#              "sr": "Bilijar",
#              "zh-hk": "\u649e\u7403",
#              "vi": "Bi-a",
#              "fi": "Biljardihalli",
#              "sv": "Biljardhall",
#              "fr": "Billard",
#              "pt-pt": "Bilhares",
#              "el": "\u03a3\u03c6\u03b1\u03b9\u03c1\u03b9\u03c3\u03c4\u03ae\u03c1\u03b9\u03bf",
#              "de": "Billard"
#            },
#            "name": "Billiards"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u4fdd\u9f84\u7403\u9986",
#              "th": "\u0e25\u0e32\u0e19\u0e42\u0e1a\u0e27\u0e4c\u0e25\u0e34\u0e07",
#              "nb": "Bowling",
#              "et": "Keeglisaal",
#              "tr": "Bowling Salonu",
#              "zh-tw": "\u4fdd\u9f61\u7403\u5834",
#              "pt-br": "Pista de Boliche",
#              "nl": "Bowlingbaan",
#              "es": "Bolera",
#              "it": "Pista da bowling",
#              "da": "Bowlingbane",
#              "pl": "Kr\u0119gielnia",
#              "ro": "Pist\u0103 de bowling",
#              "lt": "Boulingas",
#              "ja": "\u30dc\u30fc\u30ea\u30f3\u30b0\u5834",
#              "lv": "Boulinga z\u0101le",
#              "ru": "\u0411\u043e\u0443\u043b\u0438\u043d\u0433",
#              "he": "\u05d1\u05d0\u05d5\u05dc\u05d9\u05e0\u05d2",
#              "ar": "\u0645\u0644\u0639\u0628 \u0628\u0648\u0644\u064a\u0646\u062c",
#              "cs": "Bowlingov\u00e1 dr\u00e1ha",
#              "hr": "Kuglana",
#              "ko": "\ubcfc\ub9c1\uc7a5",
#              "sr": "Kuglana",
#              "zh-hk": "\u4fdd\u9f61\u7403\u5834",
#              "vi": "Ch\u01a1i bowling",
#              "fi": "Keilarata",
#              "sv": "Bowlinghall",
#              "fr": "Piste de bowling",
#              "pt-pt": "Pista de Bowling",
#              "el": "\u039c\u03c0\u03cc\u03bf\u03c5\u03bb\u03b9\u03bd\u03b3\u03ba",
#              "de": "Kegelbahn"
#            },
#            "name": "Bowling Alley"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u8d4c\u573a",
#              "th": "\u0e04\u0e32\u0e2a\u0e34\u0e42\u0e19",
#              "nb": "Kasino",
#              "et": "Kasiino",
#              "tr": "Kumarhane",
#              "zh-tw": "\u8ced\u5834",
#              "pt-br": "Cassino",
#              "nl": "Casino",
#              "es": "Casino",
#              "it": "Casin\u00f2",
#              "da": "Casino",
#              "pl": "Kasyno",
#              "ro": "Cazino",
#              "lt": "Kazino",
#              "ja": "\u30ab\u30b8\u30ce",
#              "lv": "Kazino",
#              "ru": "\u041a\u0430\u0437\u0438\u043d\u043e",
#              "he": "\u05e7\u05d6\u05d9\u05e0\u05d5",
#              "ar": "\u0643\u0627\u0632\u064a\u0646\u0648",
#              "cs": "Kasino",
#              "hr": "Kasino",
#              "ko": "\uce74\uc9c0\ub178",
#              "sr": "Kazino",
#              "zh-hk": "\u8ced\u5834",
#              "vi": "S\u00f2ng b\u1ea1c",
#              "fi": "Kasino",
#              "sv": "Casino",
#              "fr": "Casino",
#              "pt-pt": "Casino",
#              "el": "\u039a\u03b1\u03b6\u03af\u03bd\u03bf",
#              "de": "Kasino"
#            },
#            "name": "Casino"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u7535\u5f71\u9662",
#              "th": "\u0e42\u0e23\u0e07\u0e20\u0e32\u0e1e\u0e22\u0e19\u0e15\u0e23\u0e4c",
#              "nb": "Kino",
#              "et": "Kino",
#              "tr": "Sinema",
#              "zh-tw": "\u96fb\u5f71\u9662",
#              "pt-br": "Cinema",
#              "nl": "Bioscoop",
#              "es": "Cine",
#              "it": "Cinema",
#              "da": "Biograf",
#              "pl": "Kino",
#              "ro": "Cinematograf",
#              "lt": "Kino teatras",
#              "ja": "\u6620\u753b\u9928",
#              "lv": "Kinote\u0101tris",
#              "ru": "\u041a\u0438\u043d\u043e\u0442\u0435\u0430\u0442\u0440",
#              "he": "\u05e7\u05d5\u05dc\u05e0\u05d5\u05e2",
#              "ar": "\u0633\u064a\u0646\u0645\u0627",
#              "cs": "Kino",
#              "hr": "Kino",
#              "ko": "\uadf9\uc7a5",
#              "sr": "Bioskop",
#              "zh-hk": "\u96fb\u5f71\u9662",
#              "vi": "R\u1ea1p chi\u1ebfu phim",
#              "fi": "Elokuvateatteri",
#              "sv": "Biograf",
#              "fr": "Cin\u00e9ma",
#              "pt-pt": "Cinema",
#              "el": "\u039a\u03b9\u03bd\u03b7\u03bc\u03b1\u03c4\u03bf\u03b3\u03c1\u03ac\u03c6\u03bf\u03c2",
#              "de": "Kino"
#            },
#            "name": "Cinema"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u5386\u53f2\u7eaa\u5ff5\u7891",
#              "th": "\u0e2d\u0e19\u0e38\u0e2a\u0e32\u0e27\u0e23\u0e35\u0e22\u0e4c\u0e17\u0e32\u0e07\u0e1b\u0e23\u0e30\u0e27\u0e31\u0e15\u0e34\u0e28\u0e32\u0e2a\u0e15\u0e23\u0e4c",
#              "nb": "Historisk monument",
#              "et": "Ajalooline ausammas",
#              "tr": "Tarihi An\u0131t",
#              "zh-tw": "\u6b77\u53f2\u7d00\u5ff5\u7891",
#              "pt-br": "Monumento Hist\u00f3rico",
#              "nl": "Historisch monument",
#              "es": "Monumento hist\u00f3rico",
#              "it": "Monumento storico",
#              "da": "Historisk monument",
#              "pl": "Pomnik historyczny",
#              "ro": "Monument istoric",
#              "lt": "Istorinis monumentas",
#              "ja": "\u907a\u8de1",
#              "lv": "V\u0113sturisks piemineklis",
#              "ru": "\u041f\u0430\u043c\u044f\u0442\u043d\u0438\u043a \u0438\u0441\u0442\u043e\u0440\u0438\u0438",
#              "he": "\u05d0\u05e0\u05d3\u05e8\u05d8\u05d4 \u05d4\u05e1\u05d8\u05d5\u05e8\u05d9\u05ea",
#              "ar": "\u0622\u062b\u0627\u0631 \u062a\u0627\u0631\u064a\u062e\u064a\u0629",
#              "cs": "Historick\u00fd monument",
#              "hr": "Povijesni spomenik",
#              "ko": "\uc5ed\uc0ac\uc801 \uae30\ub150\ubb3c",
#              "sr": "Istorijski spomenik",
#              "zh-hk": "\u6b77\u53f2\u7d00\u5ff5\u7891",
#              "vi": "\u0110\u00e0i t\u01b0\u1edfng ni\u1ec7m l\u1ecbch s\u1eed",
#              "fi": "Muistomerkki",
#              "sv": "Historiskt monument",
#              "fr": "Monument historique",
#              "pt-pt": "Monumento Hist\u00f3rico",
#              "el": "\u0399\u03c3\u03c4\u03bf\u03c1\u03b9\u03ba\u03cc \u03bc\u03bd\u03b7\u03bc\u03b5\u03af\u03bf",
#              "de": "Denkmal"
#            },
#            "name": "Historical Monument"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u5386\u53f2\u535a\u7269\u9986",
#              "th": "\u0e1e\u0e34\u0e1e\u0e34\u0e18\u0e20\u0e31\u0e13\u0e11\u0e4c\u0e1b\u0e23\u0e30\u0e27\u0e31\u0e15\u0e34\u0e28\u0e32\u0e2a\u0e15\u0e23\u0e4c",
#              "nb": "Historisk museum",
#              "et": "Ajaloomuuseum",
#              "tr": "Tarih M\u00fczesi",
#              "zh-tw": "\u6b77\u53f2\u535a\u7269\u9928",
#              "pt-br": "Museu de Hist\u00f3ria",
#              "nl": "Historisch museum",
#              "es": "Museo hist\u00f3rico",
#              "it": "Museo di storia",
#              "da": "Historiemuseum",
#              "pl": "Muzeum historyczne",
# ...
#              "vi": "H\u1ed3",
#              "fi": "J\u00e4rvi",
#              "sv": "Sj\u00f6",
#              "fr": "Lac",
#              "pt-pt": "Lago",
#              "el": "\u039b\u03af\u03bc\u03bd\u03b7",
#              "de": "See"
#            },
#            "name": "Lake"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u6d77\u6d0b",
#              "th": "\u0e21\u0e2b\u0e32\u0e2a\u0e21\u0e38\u0e17\u0e23",
#              "nb": "Hav",
#              "et": "Ookean",
#              "tr": "Okyanus",
#              "zh-tw": "\u6d77\u6d0b",
#              "pt-br": "Oceano",
#              "nl": "Oceaan",
#              "es": "Oc\u00e9ano",
#              "it": "Oceano",
#              "da": "Ocean",
#              "pl": "Ocean",
#              "ro": "Ocean",
#              "lt": "Vandenynas",
#              "ja": "\u6d77\u6d0b\u56f3",
#              "lv": "Oke\u0101ns",
#              "ru": "\u041e\u043a\u0435\u0430\u043d",
#              "he": "\u05d0\u05d5\u05e7\u05d9\u05e0\u05d5\u05e1",
#              "ar": "\u0645\u062d\u064a\u0637",
#              "cs": "Oce\u00e1n",
#              "hr": "Ocean",
#              "ko": "\ud574\uc591",
#              "sr": "Okean",
#              "zh-hk": "\u6d77\u6d0b",
#              "vi": "\u0110\u1ea1i d\u01b0\u01a1ng",
#              "fi": "Valtameri",
#              "sv": "Ocean",
#              "fr": "Oc\u00e9an",
#              "pt-pt": "Oceano",
#              "el": "\u03a9\u03ba\u03b5\u03b1\u03bd\u03cc\u03c2",
#              "de": "Meere"
#            },
#            "name": "Ocean"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u5176\u4ed6\u6c34\u666f",
#              "th": "\u0e04\u0e38\u0e13\u0e25\u0e31\u0e01\u0e29\u0e13\u0e30\u0e17\u0e32\u0e07\u0e19\u0e49\u0e33\u0e2d\u0e37\u0e48\u0e19\u0e46",
#              "nb": "Andre vannelementer",
#              "et": "Muu veeobjekt",
#              "tr": "Di\u011fer Sulak Yerler",
#              "zh-tw": "\u5176\u4ed6\u6c34\u6587\u5716\u5fb5",
#              "pt-br": "Outro Recurso H\u00eddrico",
#              "nl": "Overige Waterpartij",
#              "es": "Otras entidades relacionadas con el agua",
#              "it": "Feature acqua - Altro",
#              "da": "Andre vandobjekter",
#              "pl": "Obiekty wodne \u2014 inne",
#              "ro": "Alte forme de ap\u0103",
#              "lt": "Kitas vandens elementas",
#              "ja": "\u305d\u306e\u4ed6\u306e\u6c34\u57df",
#              "lv": "Cits \u016bdens elements",
#              "ru": "\u0414\u0440\u0443\u0433\u0438\u0435 \u0432\u043e\u0434\u043d\u044b\u0435 \u043e\u0431\u044a\u0435\u043a\u0442\u044b",
#              "he": "\u05ea\u05db\u05d5\u05e0\u05ea \u05de\u05d9\u05dd \u05d0\u05d7\u05e8\u05ea",
#              "ar": "\u0645\u0639\u0627\u0644\u0645 \u0645\u0627\u0626\u064a\u0629 \u0623\u062e\u0631\u0649",
#              "cs": "Jin\u00fd vodn\u00ed prvek",
#              "hr": "Drugi vodeni geoobjekt",
#              "ko": "\uae30\ud0c0 \uc218\uc0c1 \ud53c\ucc98",
#              "sr": "Drugi vodeni objekti",
#              "zh-hk": "\u5176\u4ed6\u6c34\u6587\u5716\u5fb5",
#              "vi": "\u0110\u1eb7c \u0111i\u1ec3m v\u1ec1 N\u01b0\u1edbc Kh\u00e1c",
#              "fi": "Muu vesist\u00f6kohde",
#              "sv": "Annat vattengeoobjekt",
#              "fr": "Autres entit\u00e9s hydrographiques",
#              "pt-pt": "Outro Elemento Aqu\u00e1tico",
#              "el": "\u0386\u03bb\u03bb\u03b1 \u03c5\u03b4\u03ac\u03c4\u03b9\u03bd\u03b1 \u03c3\u03c4\u03bf\u03b9\u03c7\u03b5\u03af\u03b1",
#              "de": "Sonstige Wasser-Features"
#            },
#            "name": "Other Water Feature"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u7901\u77f3",
#              "th": "\u0e41\u0e19\u0e27\u0e1b\u0e30\u0e01\u0e32\u0e23\u0e31\u0e07",
#              "nb": "Rev",
#              "et": "Riff",
#              "tr": "Resif",
#              "zh-tw": "\u6697\u7901",
#              "pt-br": "Recife",
#              "nl": "Rif",
#              "es": "Arrecife",
#              "it": "Barriera corallina",
#              "da": "Rev",
#              "pl": "Rafa",
#              "ro": "Recif",
#              "lt": "Rifas",
#              "ja": "\u7901",
#              "lv": "Rifs",
#              "ru": "\u0420\u0438\u0444",
#              "he": "\u05e8\u05d9\u05e3",
#              "ar": "\u0634\u0650\u0639\u0627\u0628 \u0645\u0631\u062c\u0627\u0646\u064a\u0629",
#              "cs": "\u00dates",
#              "hr": "Greben",
#              "ko": "\uc554\ucd08",
#              "sr": "Greben",
#              "zh-hk": "\u6697\u7901",
#              "vi": "R\u1ea1n san h\u00f4",
#              "fi": "Riutta",
#              "sv": "Rev",
#              "fr": "R\u00e9cif",
#              "pt-pt": "Recife",
#              "el": "\u038e\u03c6\u03b1\u03bb\u03bf\u03c2",
#              "de": "Riff"
#            },
#            "name": "Reef"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u6c34\u5e93",
#              "th": "\u0e2d\u0e48\u0e32\u0e07\u0e40\u0e01\u0e47\u0e1a\u0e19\u0e49\u0e33",
#              "nb": "Reservoar",
#              "et": "Reservuaar",
#              "tr": "Rezervuar",
#              "zh-tw": "\u6c34\u5eab",
#              "pt-br": "Reservat\u00f3rio",
#              "nl": "Reservoir",
#              "es": "Embalse",
#              "it": "Serbatoio",
#              "da": "Reservoir",
#              "pl": "Zbiornik",
#              "ro": "Rezervor",
#              "lt": "Rezervuaras",
#              "ja": "\u8caf\u6c34\u6c60",
#              "lv": "Rezervu\u0101rs",
#              "ru": "\u0412\u043e\u0434\u043e\u0445\u0440\u0430\u043d\u0438\u043b\u0438\u0449\u0435",
#              "he": "\u05de\u05d0\u05d2\u05e8",
#              "ar": "\u062e\u0632\u0627\u0626\u0646 \u0645\u0627\u0626\u064a",
#              "cs": "Vodn\u00ed n\u00e1dr\u017e",
#              "hr": "Rezervoar",
#              "ko": "\uc800\uc218\uc9c0",
#              "sr": "Rezervoar",
#              "zh-hk": "\u6c34\u5eab",
#              "vi": "H\u1ed3 ch\u1ee9a",
#              "fi": "Tekoj\u00e4rvi",
#              "sv": "Reservoar",
#              "fr": "R\u00e9servoir",
#              "pt-pt": "Reservat\u00f3rio",
#              "el": "\u0394\u03b5\u03be\u03b1\u03bc\u03b5\u03bd\u03ae",
#              "de": "Speichersee"
#            },
#            "name": "Reservoir"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u5927\u6d77",
#              "th": "\u0e17\u0e30\u0e40\u0e25",
#              "nb": "Sj\u00f8",
#              "et": "Meri",
#              "tr": "Deniz",
#              "zh-tw": "\u6d77\u6d0b",
#              "pt-br": "Mar",
#              "nl": "Zee",
#              "es": "Mar",
#              "it": "Mare",
#              "da": "Hav",
#              "pl": "Morze",
#              "ro": "Mare",
#              "lt": "J\u016bra",
#              "ja": "\u6d77",
#              "lv": "J\u016bra",
#              "ru": "\u041c\u043e\u0440\u0435",
#              "he": "\u05d9\u05dd",
#              "ar": "\u0628\u062d\u0631",
#              "cs": "Mo\u0159e",
#              "hr": "More",
#              "ko": "\ubc14\ub2e4",
#              "sr": "More",
#              "zh-hk": "\u6d77\u6d0b",
#              "vi": "Bi\u1ec3n",
#              "fi": "Meri",
#              "sv": "Hav",
#              "fr": "Mer",
#              "pt-pt": "Mar",
#              "el": "\u0398\u03ac\u03bb\u03b1\u03c3\u03c3\u03b1",
#              "de": "Meer"
#            },
#            "name": "Sea"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u5ce1\u6e7e",
#              "th": "\u0e40\u0e2a\u0e35\u0e22\u0e07",
#              "nb": "Sund",
#              "et": "Merekitsus",
#              "tr": "Su Yolu",
#              "zh-tw": "\u6d77\u7063",
#              "pt-br": "Som",
#              "nl": "Zee-inham",
#              "es": "Brazo de mar",
#              "it": "Canale",
#              "da": "Sund",
#              "pl": "Cie\u015bnina 1",
#              "ro": "Canal de mare",
#              "lt": "Garsas",
#              "ja": "\u97f3",
#              "lv": "Zunds",
#              "ru": "\u041f\u0440\u043e\u043b\u0438\u0432",
#              "he": "\u05de\u05d9\u05e6\u05e8",
#              "ar": "\u0635\u0648\u062a",
#              "cs": "Pr\u016fliv",
#              "hr": "Zvuk",
#              "ko": "\ud558\uad6c",
#              "sr": "Zvuk",
#              "zh-hk": "\u6d77\u7063",
#              "vi": "Eo bi\u1ec3n",
#              "fi": "Salmi",
#              "sv": "Sund",
#              "fr": "Bras de mer",
#              "pt-pt": "Bra\u00e7o de Mar",
#              "el": "\u03a0\u03bf\u03c1\u03b8\u03bc\u03cc\u03c2",
#              "de": "Sund"
#            },
#            "name": "Sound"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u6cc9",
#              "th": "\u0e24\u0e14\u0e39\u0e43\u0e1a\u0e44\u0e21\u0e49\u0e1c\u0e25\u0e34",
#              "nb": "Kilde",
#              "et": "Kevad",
#              "tr": "P\u0131nar",
#              "zh-tw": "\u6cc9",
#              "pt-br": "Fonte",
#              "nl": "Bron",
#              "es": "Primavera",
#              "it": "Molla",
#              "da": "Kilde",
#              "pl": "\u0179r\u00f3d\u0142o",
#              "ro": "Izvor",
#              "lt": "\u0160altinis",
#              "ja": "\u6cc9",
#              "lv": "Pavasaris",
#              "ru": "\u0418\u0441\u0442\u043e\u0447\u043d\u0438\u043a",
#              "he": "\u05d0\u05d1\u05d9\u05d1",
#              "ar": "\u0631\u0628\u064a\u0639",
#              "cs": "Pramen",
#              "hr": "Izvor",
#              "ko": "\uc0d8",
#              "sr": "Izvor",
#              "zh-hk": "\u6cc9",
#              "vi": "Su\u1ed1i",
#              "fi": "L\u00e4hde",
#              "sv": "K\u00e4lla",
#              "fr": "Source",
#              "pt-pt": "Fonte",
#              "el": "\u03a0\u03b7\u03b3\u03ae",
#              "de": "Fr\u00fchling"
#            },
#            "name": "Spring"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u6d77\u5ce1",
#              "th": "\u0e0a\u0e48\u0e2d\u0e07\u0e41\u0e04\u0e1a",
#              "nb": "Strede",
#              "et": "V\u00e4in",
#              "tr": "Bo\u011faz",
#              "zh-tw": "\u6d77\u5cfd",
#              "pt-br": "V\u00f3rtice",
#              "nl": "Zeestraat",
#              "es": "Estrecho",
#              "it": "Stretto",
#              "da": "Str\u00e6de",
#              "pl": "Cie\u015bnina 2",
#              "ro": "Str\u00e2mtoare",
#              "lt": "S\u0105siauris",
#              "ja": "\u6d77\u5ce1",
#              "lv": "J\u016bras \u0161aurums",
#              "ru": "\u041f\u0440\u043e\u043b\u0438\u0432",
#              "he": "\u05de\u05d9\u05e6\u05e8",
#              "ar": "\u0645\u0636\u064a\u0642",
#              "cs": "Pr\u016fliv",
#              "hr": "Tjesnac",
#              "ko": "\ud574\ud611",
#              "sr": "Moreuz",
#              "zh-hk": "\u6d77\u5cfd",
#              "vi": "B\u1edd eo bi\u1ec3n",
#              "fi": "Kapeikko",
#              "sv": "Sund",
#              "fr": "D\u00e9troit",
#              "pt-pt": "Estreito",
#              "el": "\u03a3\u03c4\u03b5\u03bd\u03ac",
#              "de": "Meeresstra\u00dfe"
#            },
#            "name": "Strait"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u6cb3\u6d41",
#              "th": "\u0e41\u0e21\u0e48\u0e19\u0e49\u0e33",
#              "nb": "Str\u00f8mming",
#              "et": "Voogesitus",
#              "tr": "Ak\u0131\u015f",
#              "zh-tw": "\u6cb3\u6d41",
#              "pt-br": "C\u00f3rrego",
#              "nl": "Streamen",
#              "es": "Flujo",
#              "it": "Flusso",
#              "da": "Vandl\u00f8b",
#              "pl": "Strumie\u0144",
#              "ro": "Transmisie",
#              "lt": "Upelis",
#              "ja": "\u5c0f\u5ddd",
#              "lv": "Straum\u0113t",
#              "ru": "\u0420\u0443\u0447\u0435\u0439",
#              "he": "\u05d6\u05e8\u05dd",
#              "ar": "\u062a\u062f\u0641\u0642",
#              "cs": "Stream",
#              "hr": "Tok podataka",
#              "ko": "\uac1c\uc6b8",
#              "sr": "Potok",
#              "zh-hk": "\u6cb3\u6d41",
#              "vi": "D\u00f2ng su\u1ed1i",
#              "fi": "Joki",
#              "sv": "Str\u00f6mma",
#              "fr": "Mode continu",
#              "pt-pt": "Stream",
#              "el": "\u03a1\u03b5\u03cd\u03bc\u03b1",
#              "de": "Wasserlauf"
#            },
#            "name": "Stream"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u7011\u5e03",
#              "th": "\u0e19\u0e49\u0e33\u0e15\u0e01",
#              "nb": "Foss",
#              "et": "Kosk",
#              "tr": "\u015eelale",
#              "zh-tw": "\u7011\u5e03",
#              "pt-br": "Cachoeira",
#              "nl": "Waterval",
#              "es": "Cascada",
#              "it": "Cascata",
#              "da": "Vandfald",
#              "pl": "Wodospad",
#              "ro": "Cascad\u0103",
#              "lt": "Krioklys",
#              "ja": "\u6edd",
#              "lv": "\u016adenskritums",
#              "ru": "\u0412\u043e\u0434\u043e\u043f\u0430\u0434",
#              "he": "\u05de\u05e4\u05dc",
#              "ar": "\u0634\u0644\u0627\u0644",
#              "cs": "Vodop\u00e1d",
#              "hr": "Vodopad",
#              "ko": "\ud3ed\ud3ec",
#              "sr": "Vodopad",
#              "zh-hk": "\u7011\u5e03",
#              "vi": "Th\u00e1c n\u01b0\u1edbc",
#              "fi": "Vesiputous",
#              "sv": "Vattenfall",
#              "fr": "Cascade",
#              "pt-pt": "Catarata",
#              "el": "\u039a\u03b1\u03c4\u03b1\u03c1\u03c1\u03ac\u03ba\u03c4\u03b7\u03c2",
#              "de": "Wasserfall"
#            },
#            "name": "Waterfall"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u4e95",
#              "th": "\u0e1a\u0e48\u0e2d",
#              "nb": "Br\u00f8nn",
#              "et": "Kaev",
#              "tr": "Kuyu",
#              "zh-tw": "\u4e95",
#              "pt-br": "Po\u00e7o",
#              "nl": "Put",
#              "es": "Pozo",
#              "it": "Pozzo",
#              "da": "Br\u00f8nd",
#              "pl": "Szyb",
#              "ro": "Sond\u0103 de foraj",
#              "lt": "Gr\u0119\u017einys",
#              "ja": "\u4e95\u6238",
#              "lv": "Avots",
#              "ru": "\u041a\u043e\u043b\u043e\u0434\u0435\u0446",
#              "he": "\u05d1\u05d0\u05e8",
#              "ar": "\u0628\u0634\u0643\u0644 \u062c\u064a\u062f",
#              "cs": "Studna",
#              "hr": "Bunar",
#              "ko": "\uc6b0\ubb3c",
#              "sr": "Bu\u0161otina",
#              "zh-hk": "\u4e95",
#              "vi": "Gi\u1ebfng",
#              "fi": "Kaivo",
#              "sv": "Brunn",
#              "fr": "Puits",
#              "pt-pt": "Po\u00e7o",
#              "el": "\u03a6\u03c1\u03ad\u03b1\u03c1",
#              "de": "Brunnen"
#            },
#            "name": "Well"
#          },
#          {
#            "localizedNames": {
#              "zh-cn": "\u7801\u5934",
#              "th": "\u0e17\u0e48\u0e32\u0e40\u0e23\u0e37\u0e2d",
#              "nb": "Kai",
#              "et": "Sadamasild",
#              "tr": "\u0130skele",
#              "zh-tw": "\u78bc\u982d",
#              "pt-br": "Cais",
#              "nl": "Kade",
#              "es": "Atracadero",
#              "it": "Pontile",
#              "da": "Brygge",
#              "pl": "Nabrze\u017ce",
#              "ro": "Chei",
#              "lt": "Prieplauka",
#              "ja": "\u6ce2\u6b62\u5834",
#              "lv": "Ku\u0123u piest\u0101tne",
#              "ru": "\u041f\u0440\u0438\u0447\u0430\u043b",
#              "he": "\u05de\u05d6\u05d7",
#              "ar": "\u0631\u0635\u064a\u0641 \u0627\u0644\u0645\u064a\u0646\u0627\u0621",
#              "cs": "P\u0159\u00edstavi\u0161t\u011b",
#              "hr": "Gat",
#              "ko": "\uc120\ucc3d",
#              "sr": "Kej",
#              "zh-hk": "\u78bc\u982d",
#              "vi": "C\u1ea7u c\u1ea3ng",
#              "fi": "Laivasilta",
#              "sv": "Varv",
#              "fr": "Quai",
#              "pt-pt": "Cais",
#              "el": "\u03a0\u03c1\u03bf\u03ba\u03c5\u03bc\u03b1\u03af\u03b1",
#              "de": "Werft"
#            },
#            "name": "Wharf"
#          }
#        ],
#        "name": "Water Features"
#      }
#    ],
#    "name": "POI"
#  }]

# %%
def list_categories(obj, depth = 0):       
    for category in obj['categories']:
        print('\t'*depth  + category['name'])
        if 'categories' in category:
            list_categories(category, depth + 1)

# %%
list_categories(world_geocoder.properties)
# Out:
# Address
# 	Point Address
# 	Building Name
# 	Street Address
# 	Intersection
# 	Street Name
# 	Distance Marker
# Postal
# 	Primary Postal
# 	Postal Locality
# 	Postal Extension
# Coordinate System
# 	LatLong
# 	MGRS
# 	XY
# 	YX
# 	USNG
# Populated Place
# 	Neighborhood
# 	City
# 	Subregion
# 	Region
# 	Country
# 	Zone
# POI
# 	Arts and Entertainment
# 		Amusement Park
# 		Aquarium
# 		Art Gallery
# 		Art Museum
# 		Billiards
# 		Bowling Alley
# 		Casino
# 		Cinema
# 		Historical Monument
# 		History Museum
# 		Indoor Sports
# 		Jazz Club
# 		Landmark
# 		Live Music
# 		Museum
# 		Other Arts and Entertainment
# 		Performing Arts
# 		Ruin
# 		Science Museum
# 		Tourist Attraction
# 		Wild Animal Park
# 		Zoo
# 	Education
# 		College
# 		Fine Arts School
# 		Other Education
# 		School
# 		Vocational School
# 	Food
# 		African Food
# 		American Food
# 		Argentinean Food
# 		Australian Food
# 		Austrian Food
# 		Bakery
# 		BBQ and Southern Food
# 		Belgian Food
# 		Bistro
# 		Brazilian Food
# 		Breakfast
# 		Brewpub
# 		British Isles Food
# 		Burgers
# 		Cajun and Creole Food
# 		Californian Food
# 		Caribbean Food
# 		Chicken Restaurant
# 		Chilean Food
# 		Chinese Food
# 		Coffee Shop
# 		Continental Food
# 		Creperie
# 		East European Food
# 		Fast Food
# 		Filipino Food
# 		Fondue
# 		French Food
# 		Fusion Food
# 		German Food
# 		Greek Food
# 		Grill
# 		Hawaiian Food
# 		Ice Cream Shop
# 		Indian Food
# 		Indonesian Food
# 		International Food
# 		Irish Food
# 		Italian Food
# 		Japanese Food
# 		Korean Food
# 		Kosher Food
# 		Latin American Food
# 		Malaysian Food
# 		Mexican Food
# 		Middle Eastern Food
# 		Moroccan Food
# 		Other Restaurant
# 		Pastries
# 		Pizza
# 		Polish Food
# 		Portuguese Food
# 		Russian Food
# 		Sandwich Shop
# 		Scandinavian Food
# 		Seafood
# 		Snacks
# 		South American Food
# 		Southeast Asian Food
# 		Southwestern Food
# 		Spanish Food
# 		Steak House
# 		Sushi
# 		Swiss Food
# 		Tapas
# 		Thai Food
# 		Turkish Food
# 		Vegetarian Food
# 		Vietnamese Food
# 		Winery
# 	Land Features
# 		Atoll
# 		Basin
# 		Butte
# 		Canyon
# 		Cape
# 		Cave
# 		Cliff
# 		Desert
# 		Dune
# 		Flat
# 		Forest
# 		Glacier
# 		Grassland
# 		Hill
# 		Island
# 		Isthmus
# 		Lava
# 		Marsh
# 		Meadow
# 		Mesa
# 		Mountain
# 		Mountain Range
# 		Oasis
# 		Other Land Feature
# 		Peninsula
# 		Plain
# 		Plateau
# 		Point
# 		Ravine
# 		Ridge
# 		Rock
# 		Scrubland
# 		Swamp
# 		Valley
# 		Volcano
# 		Wetland
# 	Nightlife Spot
# 		Bar or Pub
# 		Dancing
# 		Karaoke
# 		Night Club
# 		Nightlife
# 		Other Nightlife Spot
# 	Parks and Outdoors
# 		Basketball
# 		Beach
# 		Campground
# 		Diving Center
# 		Fishing
# 		Garden
# 		Golf Course
# 		Golf Driving Range
# 		Harbor
# 		Hockey
# 		Ice Skating Rink
# 		Nature Reserve
# 		Other Parks and Outdoors
# 		Park
# 		Racetrack
# 		Scenic Overlook
# 		Shooting Range
# 		Ski Lift
# 		Ski Resort
# 		Soccer
# 		Sports Center
# 		Sports Field
# 		Swimming Pool
# 		Tennis Court
# 		Trail
# 		Wildlife Reserve
# 	Professional and Other Places
# 		Advertising
# 		Ashram
# 		Banquet Hall
# 		Border Crossing
# 		Building
# 		Business Facility
# 		Cemetery
# 		Church
# 		City Hall
# 		Civic Center
# 		Convention Center
# 		Court House
# 		Dentist
# 		Doctor
# 		Embassy
# 		Factory
# 		Farm
# 		Fire Station
# 		Government Office
# 		Hospital
# 		Industrial Zone
# 		Insurance
# 		Library
# 		Livestock
# 		Medical Clinic
# 		Military Base
# 		Mill
# 		Mine
# 		Mosque
# 		Observatory
# 		Oil Facility
# 		Orchard
# 		Other Professional Place
# 		Other Religious Place
# 		Plantation
# 		Police Station
# 		Post Office
# 		Power Station
# 		Prison
# 		Public Restroom
# 		Radio Station
# 		Ranch
# 		Recreation Facility
# 		Religious Center
# 		Scientific Research
# 		Shrine
# 		Storage
# 		Synagogue
# 		Telecom
# 		Temple
# 		Tower
# 		Veterinarian
# 		Vineyard
# 		Warehouse
# 		Water Tank
# 		Water Treatment
# 	Residence
# 		Estate
# 		House
# 		Nursing Home
# 		Other Residence
# 		Residential Area
# 	Shops and Service
# 		ATM
# 		Auto Dealership
# 		Auto Maintenance
# 		Auto Parts
# 		Bank
# 		Beauty Salon
# 		Bookstore
# 		Butcher
# 		Candy Store
# 		Car Wash
# 		Childrens Apparel
# 		Clothing Store
# 		Consumer Electronics Store
# 		Convenience Store
# 		Department Store
# 		Farmers Market
# 		Fitness Center
# 		Flea Market
# 		Food and Beverage Shop
# 		Footwear
# 		Furniture Store
# 		Gas Station
# 		Grocery
# 		Home Improvement Store
# 		Market
# 		Mens Apparel
# 		Mobile Phone Shop
# 		Motorcycle Shop
# 		Office Supplies Store
# 		Other Shops and Service
# 		Pet Store
# 		Pharmacy
# 		Real Estate
# 		Repair Services
# 		Shopping Center
# 		Spa
# 		Specialty Store
# 		Sporting Goods Store
# 		Tire Store
# 		Toy Store
# 		Used Car Dealership
# 		Wholesale Warehouse
# 		Womens Apparel
# 		Yoga Studio
# 	Travel and Transport
# 		Airport
# 		Bed and Breakfast
# 		Bridge
# 		Bus Station
# 		Bus Stop
# 		Dock
# 		Ferry
# 		Heliport
# 		Hostel
# 		Hotel
# 		Marina
# 		Metro Station
# 		Motel
# 		Other Travel
# 		Parking
# 		Pier
# 		Port
# 		Rental Cars
# 		Resort
# 		Rest Area
# 		Taxi
# 		Tourist Information
# 		Train Station
# 		Travel Agency
# 		Truck Stop
# 		Tunnel
# 	Water Features
# 		Bay
# 		Canal
# 		Channel
# 		Cove
# 		Dam
# 		Delta
# 		Estuary
# 		Fjord
# 		Gulf
# 		Hot Spring
# 		Irrigation
# 		Jetty
# 		Lagoon
# 		Lake
# 		Ocean
# 		Other Water Feature
# 		Reef
# 		Reservoir
# 		Sea
# 		Sound
# 		Spring
# 		Strait
# 		Stream
# 		Waterfall
# 		Well
# 		Wharf

# %%
c1 = world_geocoder.properties.categories
len(c1)
# Out:
# 5

# %%
c2 = c1[0]
len(c2)
# Out:
# 3

# %%
c2['name']
# Out:
# 'Address'
